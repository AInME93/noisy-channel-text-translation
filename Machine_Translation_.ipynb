# %% [markdown]
# # Machine Translation using Noisy Channel
#
# Here we will attempt to translate old Irish to new Irish using Noisy Channel.
#
#
# *   We ingest our data and concatenate the words into sentences
# *   We calculate frequencies of each source word per sentence and repeat for the target words
# *   We also compute frequencies of a target word being matched by the adjacent word in the target sentence for all occurences of the source word
# *   Use Bayesian probabilities to predict the next word when translating test data:
#   **P(new|old) = P(new)P(old|new)**
#
# * We process stop words, auxililary verbs and punctuations etc separately as they are more frequent than most words and thus dominate probability calculations
#
#   **Limitations**
#
# - Cuts off rest of target sentence once end of source sentence reached

# %% [markdown]
# ## Read Files

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
import numpy as np


path_train_source = r"/content/train-source.txt"
path_train_target = r"/content/train-target.txt"

# %%
def read_file(path):

  text = []
  words = set()

  sentences = open(path, 'r', encoding='utf-8')

  sent = ""
  
  for ind, word in enumerate(sentences):

    token = word.rstrip("\n").rstrip("\t").lower()

    if token == "<s>" or token in ["'", '"']:
      # sent = sent
      continue

    elif token == '</s>':
      sent = sent[:-1]
      text.append(sent.lstrip())
      sent = ""

    else:
      sent = sent + token + " "    
  
    if token not in words:
      words.add(token)

  word_index = dict([(i, word) for i, word in enumerate(words)])

  return text, words, word_index

# %%
from difflib import SequenceMatcher as SM

def compute_frequencies(source, target):

  target_frequencies = {}
  source_to_target_frequencies = {}
  total_st_frequencies = 0

  for x in zip(source, target):

    source_words = [word for word in x[0].split(" ")]
    target_words = [word for word in x[1].split(" ")]

    # print(len(source_words), len(target_words))

    for ind, word in enumerate(source_words):

      if ind <= len(target_words) - 1:

        t_w = target_words[ind]
        # print(t_w)

        # compare similarity of the two words
        if not (SM(None, word, t_w).ratio() > 0.5 and len(min(word,t_w))/len(max(word,t_w)) > 0.5):
          t_w = compare_words(word, t_w, target_words[ind:])
          # print(t_w)
          # break

        # Add target to emission table
        # print(target_frequencies.keys())
        if t_w in target_frequencies.keys():
          target_frequencies[t_w] += 1
        else:
          target_frequencies[t_w] = 1

        # print(target_frequencies)

        # Add target to transition table for source words
        if word in source_to_target_frequencies.keys():
          if t_w in source_to_target_frequencies[word].keys():
            source_to_target_frequencies[word][t_w] += 1
          else:
            source_to_target_frequencies[word][t_w] = 1

        else:
          source_to_target_frequencies[word] ={}          
          source_to_target_frequencies[word][t_w] = 1

        total_st_frequencies += 1

  return target_frequencies, source_to_target_frequencies, total_st_frequencies

# %%
def compare_words(source, target, target_list, ind = -1):

  ind += 1

  if ind > len(target_list)-1:
    return "<PAD>"

  else:

    if SM(None, source, target).ratio() > 0.5 and len(min(source, target))/len(max(source, target)) > 0.5:
      return target

    else:
      target = target_list[ind]
      return compare_words(source, target, target_list, ind)

# %%
input_text, input_words, input_word_index = read_file(path_train_source)
target_text, target_words, target_word_index = read_file(path_train_target)

input_words.add("<PAD>")
target_words.add("<PAD>")

input_word_index[len(input_word_index)] = "<PAD>"
target_word_index[len(target_word_index)] = "<PAD>"

# %%
target_word_index[len(target_word_index)-1]
# Out:
# 'thíre'

# %%
target_frequencies, source_to_target_frequencies, total_st_frequencies = compute_frequencies(input_text, target_text)

# %% [markdown]
# ## misc

# %%
source_to_target_frequencies
# Out:
# {'cinnte': {'cinnte': 217, "'cinnte": 1, 'linn': 1},
#  'go': {'go': 7889, 'gaoth': 1, 'gceo': 1, "'go": 20, 'giota': 1},
#  'leór': {'leor': 151, 'mór': 1},
#  ',': {',': 17002},
#  'thiocfadh': {'thiocfadh': 324, 'taobhadh': 1, "'thiocfadh": 1},
#  'dóbhtha': {'dóibh': 33, 'dófa': 11},
#  'bás': {'bás': 172, 'bhás': 1},
#  'a': {'a': 23483, "'a": 37},
#  'fhagháil': {'fháil': 175, 'fhágáil': 1, 'fáil': 1},
#  'ar': {'ar': 12978,
#   'aird': 6,
#   'air': 14,
#   'airde': 6,
#   'mar': 5,
#   'abar': 1,
#   'ard': 1,
#   'arb': 1,
#   'dar': 2,
#   'art': 1,
#   "'ar": 9},
#  'imeall': {'imeall': 28},
#  'an': {'an': 22152,
#   'san': 50,
#   'aon': 12,
#   'ann': 19,
#   'achan': 1,
#   'éan': 3,
#   'ainm': 4,
#   "'an": 38,
#   'gan': 9},
#  'phuill': {'phoill': 6, 'pholl': 1},
#  '.': {'.': 22853},
#  'bhruach': {'bhruach': 46, 'bhearnach': 1},
#  'agus': {'agus': 15390,
#   'as': 10,
#   'acu': 12,
#   'ais': 21,
#   'gur': 36,
#   'anuas': 3,
#   'agatsa': 2,
#   'las': 1,
#   'abhus': 4,
#   'agamsa': 2,
#   "'agus": 44},
#  'na': {'na': 7089,
#   'ina': 741,
#   'fána': 4,
#   'dena': 1,
#   'anall': 2,
#   'cnap': 1,
#   'sna': 29,
#   'anna': 4,
#   'bánta': 1,
#   'anam': 1,
#   "'na": 2,
#   'glúna': 2,
#   'cónaí': 2,
#   'anuas': 1,
#   'dúnta': 1,
#   'lena': 5,
#   'aniar': 1,
#   'mnaoi': 1,
#   'arna': 2},
#  'cuirp': {'coirp': 11, 'chorp': 1},
#  'fosta': {'fosta': 253, 'thost': 1, 'fhostó': 1},
#  'lámh': {'lámh': 256, 'láimh': 2, 'láimhe': 2},
#  'chur': {'chur': 474,
#   'chuir': 5,
#   'chugam': 2,
#   'chuige': 2,
#   'chuig': 3,
#   'chuid': 2,
#   'chun': 5,
#   'cur': 1,
#   'chor': 1},
#  'ina': {'ina': 795,
#   'in': 1,
#   'nach': 1,
#   'imní': 1,
#   'siad': 1,
#   'néal': 1,
#   'féin': 1,
#   'sin': 1},
#  'mbás': {'mbás': 5},
#  'féin': {'féin': 2415,
#   'sin': 7,
#   'ina': 2,
#   'léi': 2,
#   'in': 2,
#   'fein': 3,
#   'éigin': 1},
#  'ghabháil': {'ghabháil': 85, 'ghabhail': 3, 'gabháil': 38, "'ghabháil": 1},
#  'de': {'de': 2165, 'den': 5, "'de": 1, 'daeid': 1},
#  'léim': {'léim': 137, 'léime': 2},
#  'isteach': {'isteach': 888,
#   'gceirteach': 1,
#   'teacht': 4,
#   'biatach': 1,
#   'sileadh': 1,
#   'doimhneacht': 1,
#   'sháthadh': 1,
#   'theacht': 5,
#   'scairteadh': 1,
#   'soitheach': 1},
#  'sa': {'sa': 892},
#  'pholl': {'pholl': 38},
#  'ghalach': {'ghalach': 2, 'ghaile': 2, 'glas': 1, 'galach': 4, 'ghealach': 1},
#  'bhí': {'bhí': 10906,
#   'bhun': 1,
#   'bachtaí': 1,
#   'bríd': 1,
#   'aibí': 1,
#   "'bhí": 11,
#   'bí': 3,
#   'sibh': 1},
#  'n-iarthar': {'iarthar': 4},
#  'dara': {'dara': 225, 'arsa': 1, 'darna': 13, 'taradh': 1},
#  'taibhlidh': {'táibhle': 2},
#  '-': {'-': 573},
#  'poll': {'poll': 47},
#  'mar': {'mar': 1622,
#   'air': 3,
#   'mura': 7,
#   'uair': 1,
#   'murar': 1,
#   'ar': 7,
#   'maireadh': 1,
#   "'mar": 3,
#   'móra': 1,
#   'mhór': 1,
#   'mór': 1,
#   'fear': 1},
#  'uisce': {"d'uisce": 1, 'uisce': 150},
#  'ann': {'ann': 1800,
#   'an': 17,
#   'gan': 6,
#   'olann': 1,
#   'inné': 1,
#   'ceann': 2,
#   'san': 2,
#   'amanna': 1,
#   'tonn': 1,
#   'ainm': 1},
#  'dhiaidh': {'dhiaidh': 491, 'diaidh': 3, 'dhiadh': 1},
#  'sin': {'sin': 4001,
#   'féin': 15,
#   'ainm': 1,
#   'shiubhán': 1,
#   'in': 6,
#   'ina': 12,
#   'sise': 1,
#   'siad': 2,
#   'san': 3,
#   'siar': 2,
#   'shin': 5,
#   'rúin': 1,
#   'fóirstin': 1,
#   'sinn': 2,
#   'inar': 1,
#   "'sin": 6,
#   'snag': 1,
#   'tine': 1},
#  'nuair': {'nuair': 2046,
#   'fuair': 2,
#   'chuir': 2,
#   'air': 5,
#   'corruair': 1,
#   "'nuair": 3,
#   'aird': 1,
#   'aréir': 1},
#  'scríobh': {'scríobh': 25},
#  'siad': {'siad': 2378,
#   'ina': 14,
#   'iad': 9,
#   'bia': 1,
#   'sin': 3,
#   'said': 1,
#   'shiúlfadh': 1,
#   'seisean': 1,
#   'stad': 1,
#   'dhiaidh': 1},
#  'litir': {'litir': 36, 'léite': 1, 'leitir': 2, 'dithi': 1},
#  'araon': {'araon': 31},
#  'i': {'i': 4132, 'di': 2},
#  'sláinte': {'sláinte': 21},
#  'mhaith': {'mhaith': 414,
#   'bheith': 4,
#   'maith': 7,
#   'aithne': 4,
#   'maithe': 1,
#   'chomhráiteach': 1,
#   'labhairt': 1,
#   'daoithi': 1},
#  'tréan': {'tréan': 34},
#  'bidh': {'bídh': 13, 'bidh': 16, 'bia': 2},
#  'aca': {'acu': 645, 'dada': 1, 'ama': 1, 'ach': 2, 'nach': 3, 'aca': 1},
#  "b'fhuras": {"b'fhurasta": 3, "b'fhurast": 7},
#  'fheiceáil': {'fheiceáil': 74, "m'fheiceáil": 1},
#  'cá': {'cá': 211, 'cár': 11, "'cá": 6},
#  'dtáinig': {'dtáinig': 193, 'tháinig': 40},
#  'chaoir-fheóil': {'chaoireoil': 1},
#  'urlár': {'urlár': 94},
#  'h-uaimhe': {'huaimhe': 40},
#  'cnámha': {'cnámha': 22, 'chnámha': 1},
#  'caorach': {'caorach': 39, 'nach': 1},
#  'gearradh': {'gearradh': 23},
#  'fheóil': {'fheoil': 10},
#  'anuas': {'anuas': 244, 'agus': 2},
#  'díobhtha': {'díobh': 20, 'díofa': 18, 'dtaobh': 1},
#  'níor': {'níor': 1044, 'níorbh': 69, "'níor": 3, 'níos': 1},
#  'bhac': {'bhac': 14, 'bhaic': 1},
#  'muid': {'muid': 394, 'tímid': 1, 'rud': 1},
#  'leis': {'leis': 2593,
#   'liomsa': 2,
#   'oileáin': 1,
#   'seisean': 9,
#   'léi': 1,
#   'ais': 3,
#   'veiste': 1,
#   'threise': 1},
#  'taiscidh': {'taisce': 4, 'taiscí': 1},
#  'deimhin': {'deimhin': 2},
#  'is': {'is': 1537, 'anois': 1, 'báis': 1, "'is": 28, 'deise': 4, 'fhios': 2},
#  'mó': {'mó': 133, 'mhó': 1, 'mór': 2},
#  'mhéaduigh': {'mhéadaigh': 20},
#  'í': {'í': 1003, 'hí': 1, 'sí': 3, 'uí': 5},
#  "d'fhág": {"d'fhág": 273},
#  'mé': {'mé': 4379, 'é': 14},
#  'corn': {'corn': 8},
#  'bhrandai': {'bhrandaí': 1},
#  'cailleadh': {'cailleadh': 37},
#  'ndearbhráithreach': {'ndeartháireacha': 3},
#  'scéal': {'scéal': 232, 'sé': 3, 'chuala': 1, 'scéala': 3},
#  'comh': {'chomh': 738,
#   'cumtha': 1,
#   'comh': 19,
#   'domhain': 1,
#   'comaoineach': 1},
#  'h-iongantach': {'hiontach': 23, 'iontach': 1},
#  'h-éagsamhalta': {'héagsúlta': 1, 'héagsamhalta': 1},
#  'nach': {'nach': 1994,
#   'rachadh': 2,
#   'inteacht': 2,
#   'teacht': 1,
#   'sna': 1,
#   'ach': 12,
#   'ionadh': 3,
#   'antráthach': 1,
#   'isteach': 1,
#   'domhnach': 1,
#   'déanamh': 3,
#   'ina': 1,
#   'acu': 2,
#   "'nach": 18,
#   'iontach': 2,
#   'bhithiúnach': 1,
#   'trodach': 1,
#   'cuachán': 1,
#   'mac': 1,
#   'tarlach': 1,
#   'feasach': 1,
#   'uchtach': 1,
#   'theach': 1,
#   'dteach': 1,
#   'millteanach': 1},
#  'mbéadh': {'mbeadh': 356, 'réidh': 1},
#  'iongantas': {'iontas': 134},
#  'orm': {'orm': 623, 'trom': 1, 'ionsorm': 1, 'ort': 1},
#  'ba': {'ba': 1948, "b'as": 1, "'ba": 8},
#  'chuma': {'chuma': 111, 'cuma': 6, 'dhubha': 1},
#  'caidé': {'cad': 200, 'caidé': 91, "'cad": 11, 'goidé': 18},
#  'dheireadh': {'dheireadh': 181, 'bhainfeadh': 1},
#  'thart': {'thart': 795,
#   'teacht': 1,
#   'laetha': 1,
#   'theacht': 1,
#   'thabhairt': 1,
#   'huaire': 1,
#   'thit': 1},
#  'liom': {'liom': 863, 'orm': 2, 'gliocas': 1, 'láimhe': 1, 'iompar': 1},
#  'rud': {'rud': 859, 'ruda': 1, 'éard': 2, 'chruaidh': 1, 'fríd': 1},
#  'bith': {'bith': 1600,
#   'áit': 4,
#   'bheith': 4,
#   'bhaint': 1,
#   'uirthi': 5,
#   'beithíoch': 1,
#   'maith': 1,
#   'aithne': 1,
#   'briste': 1,
#   'uaithi': 1,
#   'daoithi': 2,
#   'istigh': 1,
#   'bhí': 1},
#  'chreidbheáil': {'chreidbheáil': 6, 'chreidiúint': 3},
#  'anois': {'anois': 708,
#   'is': 8,
#   'dtoisí': 1,
#   "'anois": 10,
#   'anoir': 1,
#   'uaisle': 1,
#   'ansin': 1},
#  'láthair': {'láthair': 130},
#  'cháis': {'chais': 1},
#  'dhiamhraigh': {'dhiamhraigh': 1},
#  'seo': {'seo': 1452, 'anseo': 1, 'síos': 2, "'seo": 4, 'saol': 1},
#  'ní': {'ní': 4307, 'níb': 1, 'níl': 180, "'níl": 22, "'ní": 44, 'í': 2},
#  'bhodhróchaidh': {'bhodhróchaidh': 1},
#  'thú': {'thú': 174, 'tú': 16, "'tú": 1, 'thug': 1, 'bith': 1},
#  'ag': {'ag': 7694, "'ag": 5},
#  'tabhairt': {'tabhairt': 144,
#   'bheith': 1,
#   'aghaidh': 1,
#   'thabhairt': 4,
#   'rabhadh': 1,
#   'bheatha': 1},
#  'cunntais': {'cuntais': 1},
#  'ár': {'ár': 185, 'inár': 11, 'dár': 2},
#  'gcuid': {'gcuid': 233, 'airgid': 1},
#  'comhairleacha': {'comhairleacha': 5, 'comhairlí': 1, 'chomhairleacha': 1},
#  'teóir': {'teoiricí': 1},
#  'baramhlacha': {'barúlacha': 6},
#  'gur': {'gur': 1553,
#   'agus': 24,
#   'gurb': 15,
#   'gurbh': 53,
#   'gurab': 4,
#   "'gur": 3,
#   "'gurb": 1,
#   'gura': 1,
#   'gorm': 1,
#   'chur': 1,
#   'gus': 2,
#   'cur': 1},
#  'chaith': {'chaith': 329, 'achan': 1, 'seachtain': 1},
#  'sé': {'sé': 8898, 'é': 42, 'scéal': 5, 'shé': 1},
#  'nó': {'nó': 1387, 'ó': 4, "'nó": 4},
#  'seacht': {'seacht': 98, 'sheacht': 1, 'mbeannacht': 1},
#  'gabháil': {'gabháil': 239, 'bhfuil': 1, 'ghabháil': 1},
#  'síos': {'síos': 514, 'aníos': 1},
#  'dúinn': {'dúinn': 127, 'dínn': 3},
#  'san': {'san': 313, 'sa': 23, 'siar': 1, 'arán': 1, 'gan': 1, 'sin': 3},
#  'am': {'am': 283, 'amú': 1},
#  'coimhthiolán': {'comhthionól': 3, 'coimhthiolán': 4},
#  'mór': {'mór': 834, 'mhór': 5, 'móra': 1, 'mórán': 1},
#  'daoine': {'daoine': 209,
#   'daoiní': 1,
#   'airneál': 1,
#   'aige': 1,
#   'anois': 1,
#   "d'ainm": 1},
#  'cruinn': {'cruinn': 69},
#  'fá': {'fá': 970, 'fán': 2},
#  'shleas': {'shleas': 1},
#  'chnuic': {'chnoic': 57, 'chonfacha': 1, 'chonaill': 1, 'chun': 1},
#  'freeman': {'freeman': 12, 'sean': 1},
#  'bhean': {'bhean': 246,
#   'bean': 2,
#   'bheadh': 1,
#   'charn': 1,
#   'mbeadh': 1,
#   'leanbh': 1,
#   'cheart': 1},
#  'somhairle': {'somhairle': 6},
#  'cathal': {'cathal': 53},
#  'beag': {'beag': 644,
#   'bheag': 3,
#   'bean': 1,
#   'dearg': 1,
#   'bleacht': 1,
#   'beaga': 1},
#  'measc': {'measc': 10},
#  'mise': {'mise': 625,
#   'paiste': 1,
#   'máire': 2,
#   'isteach': 2,
#   'mhinice': 1,
#   'ais': 2,
#   "'mise": 3,
#   'mhuire': 1,
#   'duitse': 1},
#  'duine': {'duine': 1104,
#   'dhuine': 4,
#   'chluineas': 1,
#   'daoine': 1,
#   'in': 1,
#   "d'inis": 1,
#   'gcluin': 1},
#  'dheireannach': {'dheireanach': 35,
#   'deireanach': 3,
#   'dheireannach': 1,
#   'eangach': 1},
#  'tháinig': {'tháinig': 1711,
#   'thoisigh': 1,
#   'inid': 1,
#   "'tháinig": 1,
#   'mhuintir': 1},
#  'aníos': {'aníos': 213, 'anois': 2, 'ansin': 1, 'anseo': 3, 'os': 1},
#  'súil': {'súil': 129, 'suil': 1, 'dúil': 1, 'shúil': 2},
#  'agam': {'agam': 715,
#   'gan': 4,
#   'agamsa': 2,
#   'talaimh': 1,
#   'talamh': 1,
#   'lagaigh': 1,
#   'déanamh': 1,
#   'ata': 1},
#  'shiubhal': {'shiúl': 241, 'shiúlta': 1, 'shiúil': 2},
#  'sul': {'sula': 173, 'sular': 90, 'sul': 2},
#  'dhéanfaidh': {'dhéanfaidh': 14,
#   'déanfaidh': 9,
#   'dhéanfaimid': 1,
#   'léinidh': 1},
#  'dearmad': {'dearmad': 112, 'dhéanfad': 1, 'dhearnamar': 1, 'arsa': 1},
#  'choidhche': {'choíche': 44, 'chomh': 1},
#  "de'n": {'den': 670, 'don': 7},
#  'dreach': {'dreach': 54, 'dorcha': 1, 'raibh': 1},
#  'athair': {'athair': 83,
#   "m'athair": 4,
#   'máthair': 1,
#   "d'athair": 1,
#   'achar': 1},
#  'mháthair': {'mháthair': 313, 'athair': 1, 'mhóir': 2},
#  "d'aithris": {"d'aithris": 5, 'aithris': 1},
#  'duibhleannach': {'duibhleannach': 1},
#  'chuaidh': {'chuaigh': 1555,
#   'muid': 2,
#   'aird': 1,
#   'chuid': 1,
#   'aodh': 1,
#   'dhiaidh': 1,
#   'chun': 6,
#   'ndiaidh': 1,
#   'mhuscail': 1,
#   "'chuaigh": 1,
#   'chuig': 1},
#  'leas-oifigeach': {'leasoifigeach': 1},
#  'arís': {'arís': 326, 'air': 1, 'ais': 1},
#  'fear': {'fear': 1407,
#   'lúfar': 1,
#   'fuair': 2,
#   "b'fhearr": 1,
#   'fearr': 1,
#   'mar': 2,
#   'fhear': 4,
#   'ceart': 1,
#   'air': 2,
#   'ard': 2,
#   'fir': 1,
#   "'fear": 1,
#   'hea': 1},
#  'chuir': {'chuir': 1233,
#   'cluain': 1,
#   'chuig': 2,
#   'uirthi': 2,
#   'uair': 1,
#   "'chuir": 2,
#   'dhuine': 1,
#   'chugaibh': 1,
#   'nuair': 1},
#  'tús': {'tús': 85, 'dtús': 11},
#  'dhearbhráthair': {'dheartháir': 15},
#  'leigeadh': {'ligeadh': 34, 'ligidís': 1, 'isteach': 2, 'ligfeadh': 2},
#  'ceachtar': {'ceachtar': 48},
#  'thug': {'thug': 1180,
#   'thóg': 3,
#   'thusa': 1,
#   'thú': 1,
#   "'thug": 1,
#   'thuig': 1,
#   'orthu': 1},
#  'fríd': {'fríd': 227, 'tríd': 35, 'trí': 38},
#  'uaimh': {'uaimh': 55},
#  'uilig': {'uilig': 395,
#   'uile': 72,
#   'amuigh': 1,
#   'fuil': 1,
#   'bhfuilimid': 1,
#   'tuilte': 1},
#  'thaisbeáin': {'thaispeáin': 21},
#  "acha'n": {'gach': 11, 'achan': 2},
#  "b'ion": {"b'iontach": 1},
#  'aghaidh': {'aghaidh': 231, 'fhad': 2, 'aghaidhe': 2, 'haghaidh': 2},
#  'bán': {'bán': 126, 'bhán': 6},
#  'teannta': {'teannta': 11},
#  'ach': {'ach': 1754,
#   'nach': 4,
#   'achan': 132,
#   'teach': 3,
#   'gach': 9,
#   'acu': 6,
#   "'ach": 2,
#   'amach': 1,
#   'aici': 1,
#   'chun': 1,
#   'faic': 1},
#  'rabh': {'raibh': 3584,
#   'bhí': 1,
#   'brath': 1,
#   'riamh': 1,
#   'rath': 1,
#   'ach': 8,
#   'sracadh': 1,
#   'rabh': 1,
#   'taobh': 1,
#   'tórramh': 1,
#   'leabhar': 1,
#   'gabháil': 1,
#   'marbh': 1},
#  'comhartha': {'comhartha': 40, 'comharthaí': 1},
#  'bróin': {'bróin': 7, 'bhróin': 2},
#  'le': {'le': 3393, 'bleán': 1, 'eile': 2, 'gile': 1},
#  'air': {'air': 2110,
#   'mar': 4,
#   'ar': 7,
#   'ais': 6,
#   'aige': 3,
#   'arsa': 3,
#   'arís': 4,
#   'nuair': 2,
#   'aici': 4,
#   'ainm': 3,
#   'uair': 1,
#   'fear': 1,
#   'géar': 1,
#   'obair': 1},
#  'glór': {'glór': 93},
#  'chinn': {'chinn': 115},
#  'íseal': {'íseal': 47},
#  'suaimhneach': {'suaimhneach': 61},
#  'labhaireadh': {'labhradh': 4, 'labhraíodh': 2},
#  'dhath': {'dhath': 233, 'dhatha': 1, 'maith': 2, 'bheith': 1, 'dheamhan': 1},
#  'úr': {'úr': 118},
#  'feiceáil': {'feiceáil': 91},
#  'baint': {'baint': 129, 'bheith': 2, 'bainte': 1, 'brath': 1},
#  'as': {'as': 1378, 'agus': 9, 'aníos': 1, 'ais': 1, 'ansin': 1, 'anuas': 1},
#  'dhorcha': {'dhorcha': 23, 'domhan': 1, 'dorcha': 4},
#  'uachtar': {'uachtar': 24},
#  'scaradh': {'scaradh': 11},
#  'bunadh': {'bunadh': 66, 'bheireadh': 1},
#  'fuair': {'fuair': 663,
#   "'fuair": 1,
#   'nuair': 2,
#   'bhfear': 1,
#   'féidir': 1,
#   'uair': 1},
#  'greim': {'greim': 213, 'breith': 1},
#  'casóige': {'casóige': 1},
#  'tá': {'tá': 2067, 'atá': 112, 'á': 1, "'tá": 52, 'tráth': 1},
#  'lúthgháir': {'lúcháir': 88, 'lúchair': 1, 'lúcháire': 2},
#  'fhág': {'fhág': 101, "d'fhág": 4},
#  'tú': {'tú': 1013, 'thú': 14},
#  'neithe': {'nithe': 7},
#  'bhíthear': {'bhíothas': 51,
#   'bhíothar': 17,
#   'bhíthear': 4,
#   "'bhíothas": 1,
#   'bhíthí': 1},
#  'á': {'á': 128, 'dá': 15},
#  'duit': {'duit': 250, 'daite': 1, 'duitse': 1, 'uirthi': 1},
#  'bhfuil': {'bhfuil': 1014,
#   'bhfuilimid': 4,
#   'bilí': 1,
#   'faill': 1,
#   "'bhfuil": 1},
#  'beó': {'beo': 105, 'beó': 1},
#  'annsin': {'ansin': 1451,
#   'annsin': 1,
#   'inniu': 1,
#   'anois': 1,
#   'anseo': 1,
#   'sin': 3},
#  'fóill': {'fóill': 210, 'foill': 1},
#  'táthar': {'táthar': 13},
#  'roda': {'ruda': 3, 'rudaí': 2},
#  'chéadna': {'chéanna': 148,
#   'céanna': 6,
#   'scéala': 1,
#   'dhearna': 1,
#   'chaint': 1,
#   'chuan': 1},
#  'damh-sa': {'domhsa': 30, 'díomsa': 1, 'domsa': 5, 'arsa': 2, 'domh': 1},
#  'baineadh': {'baineadh': 85, 'truisleadh': 1, 'cliseadh': 1, 'stangadh': 1},
#  'stangadh': {'stangadh': 8, 'baineadh': 1},
#  'asam': {'asam': 33, 'arsa': 1},
#  'innis': {'inis': 54, "'inis": 1, 'dúinn': 1},
#  'damh': {'domh': 319, 'dtaobh': 1, 'dom': 43, 'ach': 2},
#  'mura': {'mura': 7},
#  'choinne': {'choinne': 185, 'coinne': 1, 'phointe': 1, 'mine': 1},
#  't-arán': {'t-arán': 9},
#  'bhrandaí': {'bhrandaí': 3, 'branda': 2},
#  'scealpaigh': {'scealpaigh': 6},
#  'cad': {'cad': 103, 'siad': 1},
#  'chuige': {'chuige': 236,
#   'aige': 1,
#   'deachaigh': 1,
#   'duine': 1,
#   'chur': 1,
#   'carraige': 1},
#  'iad': {'iad': 776, "'iad": 1, 'cad': 1, 'hiad': 1, "'cad": 1, 'ina': 1},
#  'ceart': {'ceart': 100},
#  'ghasúr': {'ghasúr': 83, 'gasúr': 1},
#  'cheana': {'cheana': 37, 'bhata': 1},
#  "mb'fhéidir": {"mb'fhéidir": 43, "b'fhéidir": 1},
#  'iarraidh': {'iarraidh': 389,
#   'raibh': 3,
#   'dearmad': 1,
#   "dh'iarraidh": 2,
#   'buaidhe': 1,
#   'bhéarfaimid': 1},
#  '?': {'?': 1145},
#  "d'amharc": {"d'amharc": 296, "dh'amharc": 1},
#  'ath-uair': {'athuair': 20},
#  'sheasamh': {'sheasamh': 123, 'seasamh': 2},
#  'áit': {'áit': 511, 'háit': 3, 'duit': 1, 'bith': 2},
#  'amharc': {'amharc': 353,
#   'hamharc': 1,
#   'thar': 1,
#   'amach': 3,
#   "d'amharc": 1,
#   "dh'amharc": 2,
#   'eadar': 1,
#   'mhara': 1},
#  'mhuinntear': {'mhuintir': 8},
#  'giota': {'giota': 94},
#  'taca': {'taca': 35},
#  'gol': {'gol': 16, 'ghol': 1},
#  'bhéarfaidh': {'bhéarfaidh': 39, 'bhéarfaimid': 1},
#  'eile': {'eile': 1197, 'ceoil': 1, 'le': 3, 'leo': 1},
#  'chathail': {'chathail': 14, 'chlainn': 1, 'cathail': 1},
#  'arsa': {'arsa': 1780,
#   'tarlach': 5,
#   'siadsan': 3,
#   'marcas': 8,
#   'neansaí': 6,
#   'ata': 1,
#   'mar': 1,
#   'ansa': 2,
#   'ndearna': 1,
#   'agamsa': 1,
#   'air': 1,
#   'feargal': 2,
#   'arís': 1,
#   'as': 2},
#  'chroith': {'chroith': 39},
#  'sásta': {'sásta': 94},
#  "d'imthigh": {"d'imigh": 410, 'léithi': 1, "'d'imigh": 2},
#  'rith': {'rith': 164, 'liatha': 1, 'maith': 1},
#  'ndiaidh': {'ndiaidh': 502, 'dath': 1, 'siad': 1},
#  'bhunaidh': {'bhunaidh': 2},
#  'beódhacht': {'beocht': 5},
#  'soilbhreacht': {'soilbhreacht': 1},
#  'naoidheanán': {'naíonán': 11},
#  'leanbán': {'leanbán': 1},
#  'shiubhail': {'shiúil': 202},
#  'un': {'chun': 325, 'suain': 2},
#  'bhaile': {'bhaile': 676,
#   'bheag': 1,
#   'abhaile': 1,
#   'bhailc': 1,
#   'aige': 1,
#   'baile': 1,
#   'bhfuil': 1,
#   'hoileáin': 1},
#  'eadar': {'eadar': 233, 'meara': 1, 'bheadh': 1},
#  "a's": {'agus': 64,
#   'as': 5,
#   "'is": 7,
#   'arsa': 3,
#   'suas': 2,
#   'naos': 1,
#   'áras': 1,
#   'péas': 1,
#   'ais': 1},
#  'ó': {'ó': 1521, 'dó': 2, 'hó': 1, 'nó': 5, "'ó": 25},
#  'sholas': {'sholas': 12},
#  'tráthnóna': {'tráthnóna': 286, "'tráthnóna": 1, 'tráth': 1},
#  'céadna': {'céanna': 124,
#   'ceann': 1,
#   'ceannann': 1,
#   'chéanna': 2,
#   'scéal': 1},
#  'tamall': {'tamall': 226, 'tamaill': 2},
#  'comhráidh': {'comhrá': 18, 'comhráidh': 6},
#  'aistidheach': {'aisteach': 24, 'aistíoch': 15},
#  'dtugann': {'dtugann': 23},
#  'spaisteóracht': {'spaisteoireacht': 11},
#  'cabhsa': {'cabhsa': 14},
#  'n-aice': {'aice': 69},
#  'theach': {'theach': 114, 'mhac': 1, 'teach': 2},
#  'cúpla': {'cúpla': 28, 'cupla': 3},
#  'péire': {'péire': 52},
#  'coinín': {'coiníní': 1, 'coinín': 4},
#  'istigh': {'istigh': 16},
#  'rópa': {'ropa': 11, 'rópa': 12},
#  'ghualainn': {'ghualainn': 48},
#  'gallach': {'gallach': 2},
#  'luin': {'lón': 1},
#  'smaolaigh': {'smólach': 1, 'smólaigh': 1},
#  'brath': {'brath': 81, 'bheadh': 1},
#  'siubhal': {'siúl': 141, 'suas': 1, 'siad': 1},
#  'labhaireann': {'labhrann': 3},
#  'shomhairle': {'shomhairle': 2},
#  'leat': {'leat': 331, 'leath': 2, 'laetha': 1},
#  'scaifte': {'scaifte': 51, 'scata': 13},
#  'maidin': {'maidin': 199, 'mhaidin': 2, 'luain': 1, 'bhain': 1},
#  'indiú': {'inniu': 5},
#  'seisean': {'seisean': 640,
#   'sise': 1,
#   'leis': 3,
#   'seachain': 1,
#   'mise': 3,
#   'bean': 2,
#   'siesean': 1,
#   'lean': 1,
#   'ligean': 1,
#   "'sin": 1},
#  'fhiafruigh': {'fhiafraigh': 4, 'fhiafraí': 1},
#  'díom-sa': {'díomsa': 6},
#  'rachainn': {'rachainn': 18, 'cheann': 1},
#  'bhal': {'bhail': 33, 'bhuel': 1, "'bhail": 23, 'cha': 1},
#  'brón': {'brón': 16},
#  'cosamhlacht': {'cosúlacht': 23},
#  'thaitin': {'thaitin': 33},
#  'fhreagra': {'fhreagra': 6},
#  'shaoilim': {'shílim': 1},
#  'dtéidhim': {'dtéim': 1},
#  'adhbhar': {'ábhar': 13},
#  'saoilim': {'sílim': 11},
#  'bhéas': {'bheas': 71},
#  'tursach': {'tuirseach': 1},
#  'tiocfaidh': {'tiocfaidh': 21, 'tiocfaimid': 1, "'tiocfaidh": 1},
#  'níl': {'níl': 262, 'ní': 2, "'níl": 2},
#  'h-eólach': {'heolach': 3},
#  'ortha': {'orthu': 340, 'ortha': 17, 'oiread': 2, 'ocras': 1, 'thart': 1},
#  'liom-sa': {'liomsa': 75},
#  'bheirt': {'bheirt': 224, 'fhear': 5, 'beirt': 1},
#  'bharr': {'bharr': 24, 'bharra': 3},
#  'gaoithe': {'gaoithe': 69, 'ghaoithe': 1, 'toit': 1},
#  'níorbh': {'níorbh': 126, 'raibh': 1},
#  'fheasach': {'fheasach': 4},
#  'oiread': {'oiread': 214, 'airde': 1, 'siad': 1},
#  'cainnte': {'cainte': 77, 'chainte': 1, 'cineál': 1},
#  'chéile': {'chéile': 522, 'scéal': 1, 'séire': 1, 'céile': 1, 'scamhláil': 1},
#  'ariamh': {'riamh': 587,
#   'roimhe': 5,
#   'maith': 1,
#   'rinneadh': 1,
#   'arsa': 2,
#   'ionam': 1,
#   'agam': 3,
#   'raibh': 3,
#   'tirim': 2,
#   'tharlach': 1},
#  'roimhe': {'roimhe': 240,
#   'riamh': 3,
#   'roimh': 59,
#   'oíche': 1,
#   'ráithe': 2,
#   'doicheall': 1,
#   'roime': 1},
#  'sheasuigh': {'sheasaigh': 196, 'sheas': 33},
#  'labhair': {'labhair': 218},
#  'tuairim': {'tuairim': 45},
#  'bharamhail': {'bharúil': 97, 'bharrúla': 1},
#  'tarngaire': {'tairngire': 1},
#  'fáidh': {'fáidh': 1, 'faiche': 1},
#  'éigin': {'éigin': 85, 'éigipt': 1, 'éigean': 1},
#  'tseórt': {'tseort': 6, 'sórt': 3},
#  'chathal': {'chathal': 10},
#  'cuir': {'cuir': 51, 'chuir': 1},
#  'scéala': {'scéala': 37, 'scolb': 1, 'scéal': 3},
#  'chugam': {'chugam': 66, 'chan': 1},
#  'cheann': {'cheann': 432,
#   'chinn': 1,
#   'ceann': 7,
#   'chionn': 4,
#   'chosa': 1,
#   'mhálainne': 1,
#   'leagann': 1,
#   'oíche': 1},
#  'tamaill': {'tamaill': 122, 'tamall': 1},
#  'bhearnaigh': {'bhearna': 1},
#  'sconnsa': {'sconsa': 1},
#  'trasna': {'trasna': 179, 'léana': 1, 'tarraingt': 1},
#  'aithghiorra': {'aicearra': 1, 'aichearra': 9},
#  'shuidh': {'shuigh': 244, 'muid': 1},
#  'lá': {'lá': 1183, 'lán': 1},
#  'geal': {'geal': 65, 'geala': 1, 'gheal': 1},
#  'ceithre': {'ceithre': 83, 'cheithre': 7, 'tithe': 1},
#  'h-uaire': {'huaire': 37, 'n-uaire': 2, "d'uaire": 1},
#  'deireannacha': {'deireanacha': 11,
#   'dheireanacha': 2,
#   'deireannacha': 2,
#   'paidreacha': 1},
#  'caithte': {'caite': 79, 'aige': 1, 'dath': 1},
#  'scríobhadh': {'scríobh': 13, 'scríobhadh': 1},
#  'trácht': {'tráchta': 1, 'trácht': 46},
#  'oifigeamhail': {'oifigiúil': 4},
#  'phríobh': {'phríobháidigh': 1},
#  'beannacht': {'beannacht': 12},
#  'chugat': {'chugat': 23, 'chur': 1, 'chuid': 1},
#  'watkins': {'watkins': 8},
#  '(': {'(': 75},
#  ')': {')': 56},
#  'fáighte': {'faighte': 4},
#  '!': {'!': 1027},
#  '23': {'23': 1},
#  'nodlaig': {'nollag': 2, 'nollaig': 10},
#  'theacht': {'theacht': 160,
#   'isteach': 10,
#   'teacht': 10,
#   'inteacht': 1,
#   'thabhairt': 1,
#   "'theacht": 1,
#   'dheich': 1,
#   'theach': 1,
#   'leat': 1},
#  'dhiamhrach': {'dhiamhrach': 1},
#  'chuartughadh': {'chuartú': 33, 'chuardach': 2},
#  'bonnógaí': {'bonnóga': 1},
#  'mallaibh': {'mallaibh': 14},
#  'leagadh': {'leagadh': 13, 'leagan': 1, 'leonadh': 1},
#  'méar': {'mear': 7, 'méar': 14, 'mór': 1},
#  'rudaí': {'rudaí': 72, 'ruda': 4},
#  'sceilp': {'sceilp': 6},
#  'chonnaic': {'chonaic': 401, 'dúchais': 1, "'chonaic": 2},
#  'rón': {'rón': 37},
#  'gceann': {'gceann': 77, 'gcionn': 8, 'ceann': 1},
#  'puill': {'poill': 4},
#  'tchím': {'tím': 21, 'tchím': 7},
#  'chuig': {'chuig': 185,
#   'chun': 1,
#   'chuigna': 10,
#   'gcuid': 1,
#   'cuairt': 1,
#   'chaith': 1},
#  'fhear': {'fhear': 416,
#   "d'fhear": 7,
#   'fear': 2,
#   'bheirt': 1,
#   'fhuar': 1,
#   "m'fhear": 3,
#   'fhéar': 1},
#  '24': {'24': 4},
#  'h-uair': {'huair': 59},
#  'bascaid': {'bascaeid': 1},
#  'aráin': {'aráin': 52, 'in': 1, 'bháin': 1, 'amháin': 1, 'árain': 1},
#  'foscailte': {'foscailte': 16, 'oscailte': 3},
#  'cuid': {'cuid': 491, 'chuid': 5, 'chuir': 1, 'acu': 6},
#  'dá': {'dá': 1057, 'á': 72, 'dhá': 14, "'dá": 3},
#  'innte': {'inti': 62},
#  'ithte': {'ite': 15},
#  'tugtha': {'tugtha': 36, 'tusa': 1},
#  'tuairisc': {'tuairisc': 3},
#  'dearbhráithreacha': {'deartháireacha': 3, 'dheartháireacha': 1},
#  "m'inchinn": {"m'inchinn": 3},
#  'mearughadh': {'mearú': 1},
#  'fir': {'fir': 364, 'fír': 16, 'fhir': 1},
#  'buaidhreadh': {'buaireamh': 40, 'buairt': 2, 'bhuairt': 1, 'buaireadh': 1},
#  'intinne': {'intinne': 24},
#  'millteanach': {'millteanach': 38},
#  'hanraí': {'hanraí': 2},
#  'reachtáil': {'reáchtáil': 21},
#  'cluinim': {'cluinim': 11},
#  'scairtigh': {'scairtigh': 12, 'scairteadh': 5},
#  's': {'s': 17, 'is': 78},
#  'w': {'w': 1},
#  'grásta': {'grásta': 13},
#  'dé': {'dé': 92},
#  'chan': {'chan': 157,
#   'gan': 1,
#   'achan': 1,
#   'cha': 1,
#   'fhágann': 1,
#   'charn': 1,
#   'can': 1,
#   'aon': 2},
#  'eagnaidheacht': {'eagnaíocht': 3, 'seanaimseartha': 1},
#  'dhaonna': {'dhaonna': 2},
#  'shábháil': {'tharrtháil': 1, 'shábháil': 28},
#  'minic': {'minic': 193},
#  'dubhairt': {'dúirt': 474,
#   "'dúirt": 2,
#   "dúirt'": 1,
#   'dhúirt': 1,
#   'ndúirt': 1,
#   'bhaile': 1,
#   'uirthi': 1},
#  "m'athair": {"m'athair": 70, 'ghasúir': 1, "'char": 1},
#  'creidte': {'creidte': 7},
#  'seán': {'sean': 64, 'seán': 30},
#  'péas': {'péas': 35},
#  'gárdaí': {'gardaí': 12},
#  'chósta': {'chósta': 8},
#  'dall': {'dall': 8, 'dalla': 1},
#  'gnoithí': {'gnoithe': 1, 'gnóthaí': 1},
#  'fiú': {'fiú': 61},
#  'bleachtaire': {'bleachtaire': 1},
#  'iomráidhteach': {'iomráiteach': 4},
#  'baile': {'baile': 155, 'le': 1, 'bhaile': 1, 'bailte': 1, 'bhaint': 1},
#  'átha': {'átha': 87},
#  'cliath': {'cliath': 92},
#  'bhreathnughadh': {'bhreathnú': 11},
#  'eólais': {'eolais': 12},
#  'deireadh': {'deireadh': 341,
#   'deiridís': 1,
#   'bheadh': 2,
#   'scaoileadh': 1,
#   'dheireadh': 2,
#   'deineadh': 1,
#   'dearfa': 1,
#   'seisean': 1,
#   'buaileadh': 1},
#  'amach': {'amach': 1448,
#   'amháin': 1,
#   'rachfá': 1,
#   'amharc': 4,
#   'folamh': 1,
#   'teach': 3,
#   'amuigh': 1,
#   'damhsa': 1,
#   'nach': 2,
#   'riamh': 1,
#   'dualtach': 1,
#   "'ach": 1,
#   'teacht': 1,
#   'ach': 4,
#   'creach': 1,
#   'bratach': 1,
#   'fanacht': 1,
#   'neach': 1},
#  'mbraigh': {'mbraighdeanas': 2},
#  'amháin': {'amháin': 741, 'seachtain': 2, 'sheáin': 1, 'riamh': 1},
#  'ndéanfaidh': {'ndéanfaidh': 6},
#  'bráthach': {'brách': 18},
#  'roimh': {'roimh': 128, 'oraibh': 1, 'riamh': 1, 'roimhe': 15},
#  'bricfeasta': {'bricfeasta': 7, 'bhricfeasta': 1},
#  'dtárlóchadh': {'dtarlóchadh': 1},
#  'dtiocfadh': {'dtiocfadh': 181},
#  'léas': {'leas': 4, 'léas': 2},
#  'feasa': {'feasa': 7},
#  'mo': {'mo': 1436, "m'aon": 1, "'mo": 4},
#  'dtéidhinn': {'dtéinn': 2},
#  'dubh-charraic': {'dúcharraig': 4},
#  "dh'iascaireacht": {"dh'iascaireacht": 3},
#  'bhínn': {'bhínn': 12},
#  'scaoileadh': {'scaoileadh': 10},
#  'bogha': {'bogha': 3, 'bheadh': 1},
#  'chaillinn': {'chaillinn': 1},
#  'saghad': {'saighead': 2, 'bogha': 1},
#  'gnáthach': {'ghnách': 2, 'gnách': 7},
#  'é': {'mé': 17, 'é': 3212, 'sé': 25, 'hé': 3, "'é": 1, 'cé': 3, 'bé': 1},
#  'thabhairt': {'thuairim': 1,
#   'thabhairt': 380,
#   'tabhairt': 4,
#   'cuairt': 1,
#   'thart': 1,
#   'mhaith': 1,
#   'thabhartha': 1},
#  'bheart': {'bheart': 3},
#  'tí': {'tí': 11},
#  'ngníomh': {'ngníomh': 4},
#  'leig': {'lig': 244, 'leis': 1},
#  'aon': {'haon': 17,
#   'aon': 695,
#   't-aon': 2,
#   'an': 4,
#   'faoin': 1,
#   'ann': 1,
#   'éan': 1,
#   'gan': 4,
#   'san': 2},
#  'shlat': {'shlat': 5},
#  'tarraingt': {'tarraingt': 200, 'orainn': 2},
#  'ruaim': {'ruaim': 7},
#  "dh'iascair": {"dh'iascaireacht": 1},
#  "b'fhéidir": {"b'fhéidir": 283, 'fhéidir': 5, "'b'fhéidir": 3},
#  'iasc': {'iasc': 12, 'éisc': 1},
#  'gan': {'gan': 1040,
#   'an': 15,
#   'ngan': 1,
#   'daingean': 1,
#   'anam': 1,
#   'bhfágann': 1,
#   'aon': 4,
#   "'gan": 3,
#   'ainm': 1,
#   'ann': 3,
#   'lann': 1,
#   'againn': 1},
#  'aiste': {'aiste': 7, 'aisti': 10},
#  'déanamh': {'déanamh': 253, 'agam': 2, 'domh': 1, 'ghaineamh': 1},
#  'féachfaidh': {'féachfaidh': 2},
#  'carraic': {'carraig': 4, 'carraigeacha': 1, 'charraig': 1},
#  'thaoibh': {'thaobh': 113, 'thaoibh': 1, 'chabhsa': 1, 'taobh': 2},
#  'láimhe': {'láimhe': 80, 'láimh': 1},
#  'deise': {'deise': 48, 'is': 2},
#  'aill': {'aill': 1},
#  'árd': {'ard': 95, 'lár': 1, 'aird': 1},
#  'féachaim': {'féachaim': 1},
#  'taobh': {'taobh': 313, 'teach': 1, 'tobar': 1},
#  'clí': {'clé': 12, 'clí': 3},
#  'streachail': {'streachail': 10},
#  'faragáin': {'fargáin': 1},
#  'fad': {'fad': 170,
#   'fear': 2,
#   'fada': 28,
#   'fhad': 1,
#   'siad': 1,
#   'fadó': 1,
#   'faid': 1,
#   'fuar': 1},
#  'dhomhain': {'dhomhain': 5, 'domhain': 1},
#  'dtaoibh': {'dtaobh': 12},
#  'beinne': {'binne': 39},
#  'sí': {'sí': 3028, 'í': 6, 'coisí': 1},
#  'tuitim': {'titim': 109},
#  'díreach': {'díreach': 326, 'isteach': 1},
#  'fairrge': {'farraige': 62, 'fear': 1, 'fharraige': 1},
#  'leóga': {'leoga': 34},
#  'gág': {'gág': 3},
#  'scáthmhar': {'scáfar': 11},
#  't-uisce': {'t-uisce': 28},
#  'munamar': {'monabhar': 14, 'monamar': 5},
#  'dorranda': {'dorránach': 1},
#  'bun': {'bun': 103, 'bhun': 3},
#  'chuartuigh': {'chuartaigh': 33, 'chuardaigh': 9},
#  'lorg': {'lorg': 82},
#  'sheáin': {'sheáin': 45, 'seáin': 1},
#  'rinne': {'rinne': 949, 'inneall': 1, 'gráinne': 1, 'róise': 1},
#  'bád': {'bád': 130, 'bán': 2, 'breá': 1},
#  'chéaslóracht': {'chéaslóireacht': 1},
#  'fríthe': {'fríthi': 14, 'tríthi': 2},
#  'ceann': {'ceann': 435, 'cheann': 3, 'cionn': 36, 'chrann': 1},
#  'ró-chumang': {'róchúng': 1},
#  'iomartha': {'iomartha': 3},
#  'pilleadh': {'pilleadh': 43, 'filleadh': 9},
#  'n-a': {'lena': 65,
#   'n-ál': 1,
#   'fána': 19,
#   'ina': 166,
#   'arna': 5,
#   'dona': 3,
#   'agna': 2,
#   'dena': 2,
#   'óna': 8,
#   'anam': 3,
#   'na': 4,
#   'nach': 1},
#  'glanadh': {'glanadh': 8},
#  'leithead': {'leithead': 20},
#  'annseo': {'anseo': 291, 'ansin': 1, 'anois': 1, 'anuas': 1},
#  'smaointiughadh': {'smaoineamh': 14, 'smaointiú': 9},
#  'cumhangas': {'chúngas': 1},
#  'coise': {'coise': 17},
#  'taoibh': {'taobh': 179, 'anois': 1, 'taoibh': 2, 'thuaidh': 1},
#  'thall': {'thall': 178, 'dhónaill': 1, 'bhaile': 1},
#  'amuigh': {'amuigh': 386, 'bhanraigh': 1, 'riamh': 1, 'muid': 1},
#  'theann': {'theann': 37},
#  'tslait': {'tslat': 4, 'tslait': 4},
#  'láimh': {'láimh': 95, 'lámh': 44, 'láidir': 1},
#  'chroidhe': {'chroí': 185, 'chuaigh': 1},
#  'nár': {'nár': 404, 'nárbh': 11, "'nár": 6, 'inár': 2, 'náir': 1},
#  'shleamhain': {'shleamhain': 14, 'shleamhnaigh': 2, 'shleamhaine': 1},
#  'chos': {'chos': 35, 'chois': 2, 'cosa': 1, 'chosa': 2},
#  'fhachair': {'fhothair': 5},
#  'chumhang': {'chúng': 6},
#  'bhuail': {'bhuail': 255, "'bhuail": 1},
#  'bualadh': {'bualadh': 46, 'buaileadh': 1},
#  'éirghe': {'éirí': 224, 'héirí': 1, 'airde': 1, "b'éigean": 1},
#  'iongantach': {'iontach': 163,
#   'contúirteach': 1,
#   'cóngarach': 1,
#   'nach': 1,
#   'nimhneach': 1},
#  'contabhair': {'contúirteach': 1},
#  'tslighe': {'tslí': 6},
#  'chnapánach': {'chnapánach': 2},
#  'fiar': {'fiar': 12},
#  'suas': {'suas': 486, 'thuas': 2},
#  'giall': {'giall': 14, 'ghialla': 1},
#  ';': {';': 1000},
#  'h-áit': {'háit': 28},
#  'in-shiubhalta': {'insiúlta': 2},
#  'cumhang': {'cúng': 5},
#  'má': {'má': 432, "'má": 7, 'más': 4},
#  'bheinn': {'bhinn': 36, 'bheinn': 3, 'bháin': 1},
#  'gheobhainn': {'gheobhainn': 10},
#  'bheó': {'bheo': 13, 'bhí': 1},
#  'mharbh': {'mharbh': 15, 'marbh': 1, 'mharaigh': 15},
#  'bhfad': {'bhfad': 282, 'bhfuair': 1, 'bhaile': 1},
#  'bunadhas': {'bunús': 26},
#  'míle': {'míle': 88, 'mhíle': 1},
#  'n-éadan': {'éadan': 26, 'n-éadan': 3},
#  'dtug': {'dtug': 78, 'thug': 20},
#  'dear': {'dear': 166, 'deara': 41},
#  'aroimhe': {'roimhe': 42},
#  'caithfidh': {'caithfidh': 102, 'caithfimid': 4, "'caithfidh": 1},
#  'éagcosamhail': {'éagosúil': 4, 'éagsúil': 2},
#  'méid': {'méid': 136, 'méide': 2, 'mhéid': 3},
#  ':': {':': 330},
#  'dtaobh': {'dtaobh': 83},
#  'mbéal': {'mbéal': 72},
#  'dóchas': {'dóchas': 32},
#  'eagla': {'eagla': 300, 'heagla': 2, "'eagla": 1},
#  'coipiughadh': {'coipeadh': 1},
#  'dtí': {'dtí': 594, 'dtína': 15, 'trí': 1},
#  'ábalta': {'ábalta': 120, 'bhéal': 1},
#  'scairt': {'scairt': 30, 'aisti': 1},
#  'dhéanamh': {'dhéanamh': 346, 'dhéan-amh': 1, 'déanamh': 1, 'talaimh': 1},
#  'fada': {'fada': 267, 'fhada': 6, 'faoina': 1},
#  'buan': {'buan': 25},
#  'ionnam': {'ionam': 32},
#  'bogadh': {'bogadh': 45, 'ngach': 2, 'bhogadh': 1},
#  'chualaidh': {'chuala': 183, 'chualaigh': 6, 'thuathail': 1, "'chuala": 1},
#  'tormán': {'tormán': 70},
#  'cos': {'cos': 59, 'cois': 2, "'cos": 1},
#  'bhris': {'bhris': 99},
#  'port': {'port': 45},
#  'feadalaighe': {'feadalaí': 13},
#  'tsuaimh': {'tsuaimhneas': 1},
#  'fonn': {'fonn': 53},
#  'thaidhbhse': {'thaibhse': 2, 'taibhse': 1},
#  'rómham': {'romham': 13},
#  'fánaidh': {'fána': 11},
#  'throm': {'throm': 24, 'trom': 3},
#  'béic': {'béic': 11},
#  'siud': {'siúd': 37, 'iad': 1},
#  'fhánaidh': {'fhána': 15},
#  'fanacht': {'fanacht': 124, 'ceanntarnocht': 1, 'amach': 2},
#  'gcúl': {'gcúl': 96, 'gcúil': 1},
#  "d'éirigh": {"d'éirigh": 480, 'dhiúltaigh': 1},
#  'righte': {'rite': 19},
#  'tobann': {'tobann': 62},
#  'sciorr': {'sciorr': 2},
#  'thuit': {'thit': 202, 'thart': 1},
#  'bhog': {'bog': 1, 'bhog': 81},
#  'h-ionfairteadh': {'únfairteadh': 1},
#  'chosaibh': {'chosa': 9},
#  'mbomaite': {'mbomaite': 10, 'bhomaite': 1},
#  'snadhmtha': {'snaidhmthe': 1},
#  'chaoin': {'chaoin': 40, 'caoin': 1},
#  'sinn': {'sinn': 79,
#   'sinne': 2,
#   'sin': 2,
#   'linn': 1,
#   'orainn': 1,
#   'dúinn': 1},
#  'h-árd': {'hard': 28},
#  'mhéad': {'mhéad': 45},
#  'scor': {'scor': 85, 'scoir': 1, 'scór': 2},
#  'againn': {'againn': 268, 'achan': 1, 'agam': 1, 'linn': 1, 'chugainn': 1},
#  'labhairt': {'labhairt': 87, 'gabháil': 1, 'labhair': 1},
#  'fhada': {'fhada': 95, 'fada': 3},
#  'chugainn': {'chugainn': 73},
#  'dhúithche': {'dhúiche': 4},
#  'thús': {'thús': 45, 'dtús': 1},
#  "d'innis": {"d'inis": 182, "'d'inis": 1, "d'eoghainín": 1},
#  'gach': {'gach': 273,
#   'ngach': 3,
#   'athrach': 1,
#   "'ach": 9,
#   'ach': 1,
#   'gcreach': 1},
#  "da'r": {'dar': 1},
#  'thárla': {'tharla': 86},
#  'aindeóin': {'ainneoin': 20, 'ann': 1},
#  'cur': {'cur': 370, 'chun': 2, 'crua': 2},
#  'iongantais': {'iontais': 45},
#  'aitis': {'aitis': 2},
#  'rónta': {'rónta': 17},
#  'chlóidh': {'chlóigh': 1},
#  'teine': {'tine': 71, 'thine': 1},
#  'dorchadas': {'dorchadas': 57},
#  'scáilí': {'scáilí': 2, 'scáileanna': 1},
#  'ruagadh': {'ruagadh': 2, 'ruaigeadh': 2},
#  'ballaí': {'ballaí': 45, 'bhalla': 1},
#  'creagach': {'creagacha': 1, 'creagach': 7, 'aghaidh': 1},
#  'gríobháin': {'gríobháin': 1},
#  'chasta': {'chasta': 6},
#  'mbíodh': {'mbíodh': 228, 'mbeadh': 7, 'mbídís': 1, 'marbh': 1, 'mbonn': 1},
#  'macalla': {'macalla': 13},
#  'éagchaoin': {'éagaoin': 1},
#  'dhá': {'dhá': 555, 'dá': 3, 'dhó': 1},
#  'thaibhleadh': {'tháibhle': 1},
#  'briseadh': {'briseadh': 80},
#  'éamoinn': {'éamainn': 8, 'éamoinn': 31},
#  'iomlán': {'hiomlán': 3,
#   'iomlán': 153,
#   'iomlána': 1,
#   'iomláin': 2,
#   't-iomlán': 1},
#  'mion-rudaí': {'mionrudaí': 2},
#  'bhaineas': {'bhaineann': 1, 'bhaineas': 4},
#  'réidhteach': {'réiteach': 19},
#  'arais': {'ais': 35, 'arís': 10, 'furast': 1, 'is': 1},
#  'scéil': {'scéil': 21},
#  'gcurtha': {'gcora': 1},
#  'léightheóra': {'léitheora': 1},
#  'críoch': {'críoch': 7},
#  'rún': {'rún': 70, 'rón': 1},
#  'cionn': {'ceann': 59, 'cionn': 152, 'cheann': 1, 'chionn': 1},
#  'bhéidh': {'bheidh': 57, 'déideadh': 1, 'beidh': 1},
#  'cineál': {'cineál': 107},
#  'tuarascbháil': {'tuarascáil': 1},
#  'dóigh': {'dóigh': 312, 'dóigha': 1, 'dhóigh': 1},
#  'ndeachaidh': {'ndeachaigh': 25},
#  'aige': {'aige': 1187,
#   'aithne': 3,
#   'air': 2,
#   'airde': 1,
#   'tuigse': 1,
#   'caite': 1,
#   'chuaigh': 2,
#   'airgid': 1,
#   'tae': 1},
#  'h-é': {'hé': 29},
#  'shláinte': {'shláinte': 9},
#  'mhisneach': {'mhisneach': 2},
#  'choinneáil': {'choinneáil': 97},
#  'leath': {'leath': 100,
#   'leataobh': 1,
#   'leathlá': 1,
#   'mbeadh': 1,
#   'bheith': 1},
#  'trí': {'trí': 221, 'thrí': 1, "'trí": 1, 'tri': 1},
#  'bhain': {'bhain': 332, 'domhain': 1, 'baile': 2, 'chaint': 1, 'bain': 1},
#  'iascaireacht': {'iascaireacht': 6, 'iascaireachta': 1},
#  'bruideadh': {'broideadh': 1, 'bruideadh': 2},
#  'díom': {'díom': 50, 'domh': 1},
#  'líneán': {'líonán': 1},
#  'garbhánach': {'garbhánach': 3},
#  'cupla': {'cúpla': 5, 'cupla': 181, 'scuab': 1},
#  'cósta': {'cósta': 3},
#  'forrán': {'forrán': 7},
#  'lean': {'lean': 65},
#  "do'n": {'den': 15, 'don': 294, "d'aon": 4, 'drong': 1},
#  'feadh': {'feadh': 173, 'fhada': 1, 'fada': 4},
#  'tuirseach': {'tuirseach': 74},
#  'obair': {'obair': 293, 'hobair': 4, 'saothair': 1, 'fuair': 1},
#  'bhéadh': {'bheadh': 535,
#   'bréag': 1,
#   'bhéadh': 1,
#   "'bheadh": 2,
#   'chéad': 1,
#   'bhéal': 1,
#   'dhéanamh': 1,
#   'bhíodh': 1,
#   'leabaidh': 1,
#   'fhad': 1},
#  'mongaigh': {'mangaigh': 1},
#  'uair': {'uair': 386, 'chuaigh': 1, 'chéaduair': 3, 'gur': 1, 'corruair': 1},
#  'éisc': {'éisc': 5},
#  'spórt': {'spórt': 5},
#  'n-iascaireacht': {'n-iascaireacht': 1},
#  'smaointigh': {'smaoinigh': 26, 'smaointigh': 11},
#  'fhéad': {'fhéad': 9},
#  'beanna': {'beanna': 11},
#  'atá': {'atá': 777, 'leat': 1, 'ata': 2, 'tá': 3, "'atá": 1},
#  'thoir': {'thoir': 60, 'ndoire': 1},
#  'beannaibh': {'beanna': 4},
#  'casadh': {'casadh': 207, "'casadh": 1, 'macasamhail': 1},
#  'gáige': {'gáige': 1},
#  'uchtach': {'uchtach': 50},
#  'léimint': {'léimint': 2},
#  'faitchíos': {'faitíos': 4, 'fhaitíos': 1},
#  'mbéinn': {'mbeinn': 32},
#  'bhliadhain': {'bhliain': 123, 'baineadh': 1, 'dhiaidh': 2, 'bliain': 1},
#  'cuma': {'cuma': 214, 'chuma': 1, 'cad': 1, 'ghruama': 1},
#  'h-uathbhásach': {'huafásach': 3},
#  'shúilibh': {'shúile': 17, 'shúilibh': 1},
#  'suimeamhail': {'suimiúil': 2},
#  'ceárnach': {'cearnach': 2},
#  'láin': {'láin': 10},
#  'mhara': {'mhara': 13, 'mara': 2, 'mhaighdean': 2},
#  'inistear': {'fheinistear': 3},
#  'h-amharc': {'hamharc': 8},
#  'mbád': {'mbád': 9},
#  'sean-iascaire': {'seaniascaire': 2},
#  'chuid': {'chuid': 778,
#   'cuid': 3,
#   'comhráidh': 1,
#   'chéad': 1,
#   'chluinstin': 1},
#  'n-oileán': {'n-oileán': 9, 'oileán': 2},
#  'béal': {'béal': 107, 'mbuaile': 1},
#  'uaimhe': {'uaimhe': 1},
#  'doiligh': {'doiligh': 59, 'dhoiligh': 1, 'dhiaidh': 1},
#  'thuigbheáil': {'thuigbheáil': 6},
#  'fuinneóg': {'fuinneog': 15, 'fuinneoig': 1},
#  'chúroí': {'chúroí': 17},
#  'bheirthí': {'bheirtí': 1},
#  'talltóir': {'talltóir': 4},
#  'gcúroí': {'gcúroí': 1},
#  'cúroí': {'cúroí': 1},
#  'lúthmhar': {'lúfar': 10},
#  'baraille': {'bairille': 4},
#  'rum': {'rum': 1},
#  'faoi': {'faoi': 280,
#   'faoin': 28,
#   'faoina': 83,
#   'fir': 1,
#   'faoinár': 2,
#   'shaoil': 1,
#   'fonóid': 1,
#   'fad': 1,
#   'aon': 1},
#  'ascail': {'ascaill': 1},
#  'bhórd': {'bhord': 13},
#  'magamhail': {'magúil': 4},
#  'ghaisceamhlacht': {'ghaisciúlacht': 3},
#  'tsean-talltóra': {'tseantalltóra': 1},
#  'faisnéis': {'faisnéis': 3},
#  'n-abóradh': {'n-abóradh': 1},
#  'shéan': {'shéan': 1},
#  'dubh': {'dubh': 176, 'dhubh': 7, 'bhí': 2},
#  'dhubhairt': {'dhúirt': 65, 'chaint': 1, 'ndúirt': 6, 'dúirt': 5},
#  'faobhar': {'faobhar': 11},
#  'fiafruigheachta': {'fiafraitheachta': 1},
#  'thíos': {'thíos': 166},
#  'duibheagán': {'duibheagán': 4},
#  'gruamdha': {'gruama': 17, 'stuama': 1, 'suaimhneas': 1},
#  'éagcaoin': {'éagaoin': 22},
#  'mhór': {'mhór': 546, 'mór': 21, 'mhóra': 1, 'mhóir': 1, 'mar': 1},
#  "b'ísle": {"b'ísle": 2, 'ísle': 2},
#  'ná': {'ná': 745, "'ná": 9},
#  'gcaithfeadh': {'gcaithfeadh': 29},
#  'mhillteanach': {'mhillteanach': 24,
#   'mhallachtaí': 1,
#   'millteanach': 4,
#   'shitheadh': 1},
#  'chor': {'chor': 139, 'orm': 1},
#  'droch-mheas': {'drochmheas': 8},
#  'chladhaireacht': {'chlaidhreacht': 1},
#  'cruthuighthe': {'cruthaithe': 7},
#  'díoghbháil': {'díobháil': 21},
#  'calmacht': {'calmachta': 1},
#  'ndéanfainn': {'ndéanfainn': 6},
#  'níos': {'níos': 199, 'níl': 1},
#  "b'óige": {"b'óige": 5, 'óige': 9},
#  "b'fheárr": {"b'fhearr": 17, 'fhearr': 22},
#  'éadtrom': {'éadrom': 47},
#  'chinneamhaint': {'chinniúint': 13},
#  'chionn': {'chionn': 40, 'cheann': 101, "cheann'": 1},
#  'bhroslughadh': {'bhroslú': 1, 'bhrostú': 3},
#  'tosaigh': {'tosaigh': 123},
#  'gurbh': {'gurbh': 101, 'gurb': 1, 'gur': 2, 'agaibh': 1},
#  'fhiú': {'fhiú': 18},
#  'cuartughadh': {'cuartú': 40, 'chuartú': 1, 'cuardach': 1, 'cuartu': 1},
#  't-amharc': {'t-amharc': 35},
#  "ó'n": {'ón': 323},
#  'uirthe': {'uirthi': 119,
#   'chuir': 1,
#   'duine': 1,
#   'nuair': 1,
#   'sluaiste': 1,
#   'aithne': 1},
#  'fhairrge': {'fharraige': 94},
#  'múr': {'múr': 9},
#  'charraic': {'charraig': 22, 'fharraige': 1},
#  'cuidiughadh': {'cuidiú': 56},
#  'bheith': {'bheith': 874,
#   'rith': 1,
#   'bhaint': 1,
#   'bheatha': 1,
#   'dúshraith': 1,
#   'maith': 2,
#   'bheir': 3,
#   'tabhairt': 1,
#   'bhinn': 1,
#   'bheag': 1},
#  'bhaint': {'bhaint': 131, 'baint': 3, 'bhaile': 2, 'albain': 1},
#  'phill': {'phill': 95, "d'fhill": 8, 'fhill': 2},
#  'dheachaidh': {'dheachaigh': 47},
#  'ghiota': {'ghiota': 32},
#  'aimhréidhteach': {'aimhréiteach': 1},
#  'nárbh': {'nárbh': 52},
#  'fhéidir': {'fhéidir': 40, "b'fhéidir": 7},
#  'thairis': {'thairis': 17},
#  'fachair': {'fothair': 1},
#  'díothbháil': {'dhíobháil': 1, 'díobháil': 2},
#  'cosaibh': {'cosa': 3},
#  'bior': {'bior': 5},
#  'iarainn': {'iarainn': 29},
#  'shlaite': {'shlaite': 2},
#  'maith': {'maith': 626,
#   'dhath': 2,
#   'mhaith': 5,
#   'bheith': 5,
#   'baint': 1,
#   'daoithi': 1,
#   'raibh': 4,
#   "'maith": 5,
#   'brath': 1,
#   'bith': 1,
#   'aigeantach': 1},
#  'thar': {'thar': 137, 'tharna': 1, 'theacht': 1, 'thaire': 1},
#  'chontabhairt': {'chontúirt': 21, 'thart': 1},
#  'truisleadh': {'truisleadh': 3,
#   'truisle': 6,
#   'baineadh': 1,
#   'tuisliú': 2,
#   'tuisle': 3,
#   'leagadh': 1},
#  'h-achrannach': {'hachrannach': 6},
#  'n-áiteachaibh': {'áiteacha': 3},
#  'gcaithfinn': {'gcaithfinn': 9},
#  'cheithre': {'cheithre': 21, 'ceithre': 3},
#  'buinn': {'boinn': 3},
#  'réir': {'réir': 131, 'aréir': 2},
#  'seal': {'seal': 121, 'mheall': 1, 'tsaoil': 1},
#  'dreapadaigh': {'dreapadaigh': 1},
#  'coisidheacht': {'coisíocht': 3},
#  'fadálach': {'fadálach': 39},
#  'corr': {'corr': 11, 'cor': 3},
#  'cointíneach': {'cointinneach': 1, 'confach': 1},
#  'tchífeadh': {'tífeadh': 8, 'tchífeadh': 2, "d'fheicfeadh": 3},
#  'gnoitheach': {'gnoitheach': 13},
#  'bhád': {'bhád': 61, 'dhá': 1, 'bhádsa': 1},
#  'cuan': {'cuan': 11},
#  'dtugamuis': {'dtugaimis': 2},
#  'linn': {'linn': 211, 'ann': 1, 'ligean': 1, 'ina': 1},
#  'thiar': {'thiar': 93, "'thiar": 1},
#  "d'athain": {"d'aithin": 18},
#  'bhomaite': {'bhomaite': 72},
#  'cruinn-chorrach': {'cruinnchorrach': 1},
#  'ghnáthach': {'ghnách': 118, 'ghnáth': 5},
#  'shaoilstin': {'shílstin': 1},
#  'sháith': {'sháith': 84, 'sháigh': 12, 'sáith': 1, 'fháil': 1},
#  'aoirde': {'airde': 9},
#  "d'fhágadh": {"d'fhágadh": 13},
#  'chearnach': {'chearnach': 1},
#  'té': {'té': 181},
#  'dheas': {'dheas': 59, 'deas': 1},
#  'chosamhlacht': {'chosúlacht': 15, 'chosúlachta': 2},
#  'fuinneóige': {'fuinneoige': 15},
#  'táirseach': {'tairseach': 1},
#  'sleamhain': {'sleamhain': 10},
#  'comhthrom': {'cothrom': 35, 'chothrom': 2},
#  'garbh': {'garbh': 62},
#  'mín': {'mín': 47, 'min': 1},
#  'imtheacht': {'imeacht': 234, 'amach': 1, 'suaimhneas': 1},
#  'bheag': {'bheag': 248,
#   'beag': 13,
#   'fhear': 1,
#   'sheang': 1,
#   'eagla': 1,
#   'easpag': 1,
#   'méabha': 1,
#   'mbeadh': 1},
#  'táirsigh': {'tairseach': 7, 'tairsigh': 1},
#  'ghrian': {'ghrian': 73, 'ghréin': 1},
#  "b'fhiú": {'fhiú': 12, "b'fhiú": 18},
#  "b'fhearrde": {'fhearrde': 1},
#  'dar': {'dar': 426, 'darbh': 1, 'dár': 5, "'dar": 3, 'ar': 2, 'dia': 7},
#  'bhfacaidh': {'bhfaca': 19},
#  'fúm': {'fúm': 11},
#  'slaite': {'slaite': 2},
#  'shé': {'shé': 9, 'sé': 3},
#  'troighthe': {'troithe': 9},
#  'fánadh': {'fána': 5},
#  'chosamhlachta': {'cosúlachta': 4, 'chosúlachta': 2},
#  'dul': {'dol': 7, 'dul': 124},
#  'dréim': {'dréim': 8},
#  'ceaptha': {'ceaptha': 6},
#  'fúni': {'fúm': 1},
#  'mheadhchoin': {'mheáchain': 1},
#  'dornán': {'cionn': 1, 'dornán': 30},
#  'luaithe': {'luaithe': 60},
#  'chéad': {'chéad': 282,
#   'chead': 3,
#   'chúpla': 1,
#   'chéaduair': 1,
#   'scéal': 1,
#   'chaibidil': 1,
#   'chéid': 2,
#   'chúrsa': 1,
#   'chatha': 1,
#   'gcéad': 1},
#  'shaoil': {'shíl': 41},
#  'rabhthar': {'rabhthar': 12, 'rabhthas': 19, 'róthrom': 1},
#  'theilgean': {'theilgean': 1},
#  'síorruidheachta': {'síoraíochta': 3},
#  'n-umar': {'umar': 1},
#  'cruinne': {'cruinne': 19},
#  'cosamhail': {'cosúil': 155, 'cathal': 1},
#  'tirim': {'tirim': 18, 'riamh': 1},
#  'gránadh': {'gránú': 3},
#  'facilis': {'facilis': 2},
#  'descensus': {'descensus': 2},
#  'fágadh': {'fágadh': 71},
#  'fhuinneóg': {'fhuinneog': 9},
#  'shamhail': {'shamhail': 25, 'shamhlaigh': 1},
#  'ró-righte': {'rórite': 1},
#  'tharraingt': {'tharraingt': 48, 'tharraing': 1},
#  'teagmháil': {'teagmháil': 2},
#  'bomaite': {'bomaite': 61},
#  'las': {'las': 26},
#  'cipín': {'cipín': 7},
#  'solais': {'solais': 14, 'soláis': 4, 'soilse': 4, 'soluis': 2},
#  'chipín': {'chipín': 4},
#  'cibé': {'cibé': 108, "'cibé": 1},
#  'fágtha': {'fágtha': 74},
#  'gcionn': {'gceann': 195, 'gcionn': 12},
#  'lasóg': {'lasóg': 14},
#  'ionnta': {'iontu': 79},
#  'dhóigh': {'dhóigh': 103},
#  'gasta': {'gasta': 65},
#  'uaim': {'uaim': 39, "uaim'": 1},
#  'buna': {'buna': 2, 'bun': 1},
#  'philleadh': {'philleadh': 2},
#  'áibhéiseach': {'áiféiseach': 1},
#  'chiaróig': {'chiaróg': 1},
#  'ngaiste': {'ngaiste': 1},
#  'gloine': {'ghloine': 8, 'gloine': 38},
#  'gáire': {'gáire': 120, 'gháire': 1},
#  'choimhéad': {'choimhéad': 12, 'choimheád': 2},
#  'h-uaisle': {'huaisle': 4},
#  'dubha': {'dubha': 36, 'dubhach': 1},
#  'snámh': {'snámh': 33, 'snámha': 2},
#  'bhallaibh': {'bhallaí': 1},
#  'sleamhna': {'sleamhna': 4},
#  'bpríosúin': {'bpríosúin': 2, 'bpríosún': 1},
#  'bhíodh': {'bhíodh': 346, 'bhídís': 1, "'bhíodh": 1},
#  'seórt': {'seort': 13, 'sórt': 6},
#  'truaighe': {'truaighe': 27, 'truaigh': 37, 'raibh': 2},
#  'tchínn': {'tínn': 4},
#  'créatúir': {'créatúir': 27},
#  'sleamhnughadh': {'sleamhnú': 8},
#  'leó': {'leo': 176, 'leis': 1},
#  'thásc': {'thasc': 1},
#  'cruaidh': {'cruaidh': 80, 'cruaidhe': 1, 'crua': 22, 'chrua': 1},
#  "d'ionnsuigh": {"d'ionsaigh": 33},
#  'n-áit': {'áit': 119, 'n-áit': 3, 'háit': 1},
#  'lámha': {'lámha': 73, 'lámh': 1},
#  'ghlúinibh': {'ghlúine': 7},
#  'bhfastódh': {'bhfastó': 3, 'bhfostó': 8, 'bhfostódh': 1, 'bhfostú': 13},
#  'scannrughadh': {'scanradh': 7, 'scanrú': 4},
#  'crith-eagla': {'critheagla': 4},
#  'mhothuigh': {'mhothaigh': 111, 'mhoithigh': 18},
#  'tocht': {'tocht': 11},
#  'cruinniughadh': {'cruinniú': 55},
#  'ndoimhneacht': {'ndoimhneacht': 8},
#  'nádúire': {'nádúire': 1},
#  'ruo': {'rud': 1},
#  'bhfuighinn': {'bhfaighinn': 18, 'bhfuighinn': 2},
#  'claonadh': {'claonadh': 7},
#  'uillinn': {'uillinn': 7},
#  'ghairbh': {'gharbh': 1, 'ghairbh': 5},
#  "d'fhéach": {"d'fhéach": 12},
#  'chlí': {'chlé': 12, 'chlí': 1, 'clé': 4},
#  'briste': {'briste': 43, 'bith': 1, 'loite': 1},
#  'mothughadh': {'mothú': 22},
#  'mhéar': {'mhéar': 21, 'méar': 1},
#  'dorcha': {'dorcha': 62, 'dhorcha': 4},
#  'léir': {'léir': 47, 'air': 1},
#  'dadadh': {'dada': 78, 'dadaidh': 30},
#  'thionntuigh': {'thiontaigh': 131},
#  'bealach': {'bealach': 193, 'bhealach': 1, 'inteacht': 1},
#  'chlochaibh': {'chlocha': 3},
#  'móra': {'móra': 81, 'mhóra': 2},
#  'chnap': {'chnap': 13},
#  'leathaigh': {'leathaigh': 6},
#  'luaidh': {'luaigh': 2},
#  'gágach': {'gágach': 5},
#  'gar': {'gar': 78, 'gur': 1, 'gas': 1, 'gan': 1},
#  'gléas': {'gléas': 35, 'ghléas': 1},
#  't-éadóchas': {'t-éadóchas': 4},
#  'fagháil': {'fáil': 106},
#  'uachtair': {'uachtar': 1, 'uachtair': 6},
#  "m'intinn": {"m'intinn": 28},
#  'iomláin': {'iomláin': 26, 'iomlán': 1},
#  'fíochmara': {'fíochmhara': 1},
#  'ciarógaí': {'ciaróga': 1},
#  'ghaiste': {'ghaiste': 11, 'ghasta': 2},
#  'ghloine': {'ghloine': 26, 'gloine': 2},
#  'aindeiseacha': {'ainniseacha': 2},
#  'thaobhanna': {'thaobhanna': 2},
#  'dhearna': {'dhearna': 4},
#  'ró-chosamhail': {'róchosúil': 2},
#  'chaill': {'chaill': 79, 'chailleamar': 1},
#  'sáruigheadh': {'sáraíodh': 1},
#  'anocht': {'anocht': 83, 'anseo': 2, 'oíche': 2},
#  "b'éadóiche": {'éadóiche': 1},
#  'do': {'do': 1345, "d'aon": 4, 'don': 2, "'do": 2, 'deoch': 1, 'dhíol': 1},
#  'dhia': {'dhia': 118, 'dia': 1},
#  'shon': {'shon': 33, 'son': 2, 'sin': 1},
#  'doimhne': {'doimhne': 19, 'doimhneacht': 2, 'dhoimhne': 1},
#  'bhreágh': {'bhreá': 22},
#  'múir': {'muir': 5, 'mhúir': 2},
#  'ribeóg': {'ribeog': 3},
#  'cheachtar': {'cheachtar': 6},
#  'mórtas': {'mórtas': 13},
#  'ngeimhreadh': {'ngeimhrí': 1},
#  'cartughadh': {'cartadh': 1},
#  'fosclaidheacha': {'fosclaíocha': 1},
#  'gurb': {'gurb': 7, 'gurbh': 1},
#  'lár': {'lár': 159, 'lá': 1, 'lán': 1},
#  'mhúir': {'mhúir': 7},
#  'chnámha': {'chnámha': 12},
#  'creagachaibh': {'creagacha': 1},
#  'loitfidhe': {'loitfí': 1},
#  'charnán': {'chamán': 2, 'charnán': 3},
#  'shocrughadh': {'shocrú': 13},
#  'breith': {'breith': 38, 'greim': 1},
#  'smaointighthe': {'smaointe': 3, 'smaoinimh': 1, 'smaointithe': 1},
#  'líon': {'líon': 31},
#  'phíopa': {'phíopa': 54, 'phiopa': 1},
#  'phócaí': {'phócaí': 10},
#  'lasógaí': {'lasóga': 3},
#  'iomchar': {'iompar': 40},
#  'scaoilte': {'scaoilte': 2},
#  'n-iomlán': {'iomlán': 3},
#  'pócaí': {'pócaí': 5},
#  'foluighthe': {'folaithe': 3, 'folaigh': 2},
#  'línín': {'línín': 6},
#  'drod': {'druidim': 3, 'drud': 6},
#  'dlúith': {'dlúth': 13},
#  'mbínn': {'mbínn': 16, 'mbeinn': 2},
#  'mhalluighthe': {'mhallaithe': 6},
#  'solas': {'solas': 66},
#  'lae': {'lae': 124},
#  'dhíth': {'dhíth': 71},
#  'bhealach': {'bhealach': 192, 'bheith': 1, 'tharla': 1},
#  'chontabhairteach': {'chontúirteach': 2},
#  'éadan': {'éadan': 24, 'héadan': 1},
#  'thoisigh': {'thoisigh': 281, 'thosaigh': 64},
#  'chruinniughadh': {'chruinniú': 30},
#  "fá'n": {'fán': 220},
#  'cnap': {'cnap': 24, 'ina': 2},
#  'fairsingeach': {'fairsingeach': 3, 'fairsinge': 1, 'fairsingeacht': 1},
#  'mhothachtail': {'mhothachtáil': 1},
#  'mholltaí': {'mhollta': 1},
#  'bhrioscarnach': {'bhrioscarnach': 1},
#  'tuile': {'tuile': 25, 'teile': 1},
#  'aoibhnis': {'aoibhnis': 7},
#  'cholainn': {'cholainn': 16},
#  'púdar': {'púdar': 15},
#  'siar': {'san': 1,
#   'siar': 186,
#   'aniar': 2,
#   'sin': 2,
#   'siad': 1,
#   'ligtear': 1},
#  'bóthar': {'bóthar': 20},
#  'troigh': {'troigh': 11},
#  'fheannta': {'fheannta': 1},
#  'leag': {'leag': 57},
#  'réidh': {'réidh': 117},
#  'gníomh': {'gníomh': 23, 'chomh': 1, 'ghníomh': 2},
#  'mearaidh': {'mearaidh': 2},
#  'féacháil': {'féacháil': 8},
#  'amhras': {'amhras': 40},
#  'shéala': {'shéala': 26, 'seal': 1},
#  ...}

# %%
input_text[0:10]
# Out:
# ['cinnte go leór , thiocfadh dóbhtha bás a fhagháil ar imeall an phuill udaí .',
#  '( bhí sé follasach go rabh an poll sin ag foscladh ar an fhairrge ar dhóigh éigin , ná líonadh agus thráigheadh an t-uisce ann .',
#  ") d'fhéadfadh siad bás fhagháil ar a bhruach agus na cuirp imtheacht ar an lán mhara amach fríd an phluais .",
#  'thiocfadh dóbhtha fosta lámh a chur ina mbás féin , a ghabháil de léim isteach sa pholl ghalach a bhí i n-iarthar an dara taibhlidh - poll mar bhéadh coire de uisce ghalach ann .',
#  "na dhiaidh sin , bhí rud éigin do-chreidte agus leamh in gach teóir de'n bheirt .",
#  'nuair a scríobh siad an litir sin bhí siad araon i sláinte mhaith agus tréan bidh aca .',
#  'bhí fhios againn i gceart nach rabh díothbhail ar bith ortha , na diomaoite de chuid bonnóg chathail tháinig muid ar an áit taiscthe a bhí aca - scealpach bheag eachar dhá charraic - agus arán agus spólaí de chaoir-fheóil shaillte ann .',
#  "b'fhuras a fheiceáil cá dtáinig an chaoir-fheóil .",
#  'ar urlár na h-uaimhe bhí cnámha caorach ar gearradh an fheóil anuas díobhtha .',
#  "séard a b'éigean do'n chaoraigh a ghabháil le beinn agus tuitim fríd an sceilp anuas san uaimh ."]

# %%
combine = list(zip(input_text, target_text))
unmatch = []
s = []
t = []
for i in range(len(combine)):
  if len(combine[i][0].split()) != len(combine[i][1].split()) and len(unmatch) < 100:
    unmatch.append(combine[i])
    s.append(combine[i][0])
    t.append(combine[i][1])

# unmatch

# %%
t_f, s_t_f = compute_frequencies(s, t)
# s

# %%
s_t_f
# Out:
# {'fhagháil-fháil': 1,
#  'ar-ar': 30,
#  'a-a': 49,
#  'bhruach-bhruach': 2,
#  'agus-agus': 30,
#  'na-na': 11,
#  'cuirp-coirp': 1,
#  'na-ina': 2,
#  'dhiaidh-dhiaidh': 1,
#  'sin-sin': 6,
#  'bhí-bhí': 33,
#  'go-go': 22,
#  'deimhin-deimhin': 1,
#  ',-,': 32,
#  'is-is': 3,
#  'mó-mó': 2,
#  'mhéaduigh-mhéadaigh': 1,
#  'muid-muid': 1,
#  'í-í': 1,
#  'ann-an': 2,
#  'súil-súil': 1,
#  'agam-agam': 5,
#  'mbéadh-mbeadh': 2,
#  'siad-siad': 1,
#  'shiubhal-shiúl': 1,
#  'sul-sula': 1,
#  'thug-thug': 1,
#  'mé-mé': 44,
#  'freeman-freeman': 4,
#  'fríd-fríd': 3,
#  'an-an': 38,
#  'uaimh-uaimh': 1,
#  'uilig-uilig': 1,
#  'thaisbeáin-thaispeáin': 1,
#  "acha'n-gach": 2,
#  "b'ion-b'iontach": 1,
#  'caidé-cad': 5,
#  'tá-tá': 5,
#  'lúthgháir-lúcháir': 1,
#  'orm-orm': 3,
#  'gur-gur': 6,
#  'fhág-fhág': 1,
#  'tú-tú': 1,
#  'neithe-nithe': 1,
#  'baineadh-baineadh': 1,
#  'stangadh-stangadh': 1,
#  'asam-asam': 1,
#  'sé-sé': 13,
#  'sheasamh-sheasamh': 1,
#  'san-san': 2,
#  'áit-áit': 10,
#  'chéadna-chéanna': 3,
#  'ag-ag': 15,
#  'amharc-amharc': 1,
#  'spaisteóracht-spaisteoireacht': 1,
#  'síos-síos': 2,
#  'cabhsa-cabhsa': 1,
#  'n-aice-aice': 1,
#  'theach-theach': 1,
#  'cúpla-cúpla': 1,
#  'péire-péire': 1,
#  'coinín-coiníní': 1,
#  'leis-leis': 1,
#  'istigh-istigh': 1,
#  'i-i': 5,
#  'rópa-ropa': 1,
#  'ghualainn-ghualainn': 1,
#  'gallach-gallach': 1,
#  'mór-mór': 2,
#  'luin-lón': 1,
#  'smaolaigh-smólach': 1,
#  'brath-brath': 1,
#  'siubhal-siúl': 1,
#  'thart-thart': 2,
#  'mé-é': 1,
#  'bhal-bhail': 1,
#  'brón-brón': 1,
#  'shomhairle-shomhairle': 1,
#  'adhbhar-ábhar': 1,
#  'saoilim-sílim': 2,
#  'bhfuil-bhfuilimid': 1,
#  'tuairim-tuairim': 1,
#  'mhaith-mhaith': 5,
#  'chuaidh-chuaigh': 1,
#  'isteach-isteach': 2,
#  'bhearnaigh-bhearna': 1,
#  'sa-sa': 6,
#  'sconnsa-sconsa': 1,
#  'trasna-trasna': 2,
#  'aithghiorra-aicearra': 1,
#  'shuidh-shuigh': 3,
#  'annsin-ansin': 5,
#  'liom-liom': 6,
#  'féin-féin': 6,
#  'ceithre-ceithre': 1,
#  'h-uaire-huaire': 1,
#  'deireannacha-deireanacha': 1,
#  'caithte-caite': 1,
#  'scríobhadh-scríobh': 1,
#  'trácht-tráchta': 1,
#  'oifigeamhail-oifigiúil': 1,
#  'cheann-chinn': 1,
#  'phríobh-phríobháidigh': 1,
#  '23-23': 1,
#  'lá-lá': 4,
#  'nodlaig-nollag': 2,
#  'tchím-tím': 1,
#  'anois-anois': 5,
#  'somhairle-somhairle': 2,
#  'watkins-watkins': 2,
#  '(-(': 3,
#  'chuig-chuig': 3,
#  'fhear-fhear': 2,
#  '24-24': 2,
#  "d'fhág-d'fhág": 1,
#  'fir-fir': 1,
#  'gabháil-gabháil': 1,
#  'grásta-grásta': 1,
#  'dé-dé': 1,
#  'chan-chan': 1,
#  'eagnaidheacht-eagnaíocht': 1,
#  'dhaonna-dhaonna': 1,
#  'shábháil-tharrtháil': 1,
#  'agus-as': 1,
#  'péas-péas': 1,
#  'gárdaí-gardaí': 1,
#  'chósta-chósta': 1,
#  'dall-dall': 1,
#  'gnoithí-gnoithe': 1,
#  'fiú-fiú': 1,
#  'bleachtaire-bleachtaire': 1,
#  'iomráidhteach-iomráiteach': 2,
#  'tháinig-tháinig': 3,
#  'as-as': 1,
#  'baile-baile': 1,
#  'átha-átha': 1,
#  'cliath-cliath': 1,
#  'bhreathnughadh-bhreathnú': 1,
#  'chur-chur': 2,
#  'eólais-eolais': 1,
#  'deireadh-deireadh': 2,
#  'fuair-fuair': 2,
#  'amach-amach': 4,
#  'rabh-raibh': 19,
#  'mbraigh-mbraighdeanas': 1,
#  'tamall-tamall': 1,
#  'roimh-roimh': 1,
#  'am-am': 1,
#  'bricfeasta-bricfeasta': 1,
#  'ann-ann': 3,
#  'nach-nach': 8,
#  "mb'fhéidir-mb'fhéidir": 1,
#  'dtárlóchadh-dtarlóchadh': 1,
#  'rud-rud': 3,
#  'éigin-éigin': 2,
#  'nó-nó': 1,
#  'dtiocfadh-dtiocfadh': 1,
#  'léas-leas': 1,
#  'beag-beag': 1,
#  'feasa-feasa': 1,
#  'mo-mo': 8,
#  'cheann-cheann': 1,
#  'dá-dá': 3,
#  'dtéidhinn-dtéinn': 1,
#  'dubh-charraic-dúcharraig': 2,
#  "dh'iascaireacht-dh'iascaireacht": 1,
#  'mar-mar': 6,
#  'nuair-nuair': 3,
#  'bhínn-bhínn': 1,
#  'scaoileadh-scaoileadh': 1,
#  'le-le': 10,
#  'bogha-bogha': 1,
#  'chaillinn-chaillinn': 1,
#  'saghad-saighead': 1,
#  'ba-ba': 7,
#  'gnáthach-ghnách': 1,
#  'ghabháil-ghabháil': 2,
#  'é-mé': 1,
#  'thabhairt-thuairim': 1,
#  'chaith-chaith': 1,
#  'ruaim-ruaim': 1,
#  "dh'iascair-dh'iascaireacht": 1,
#  'fá-fá': 4,
#  'dheireadh-dheireadh': 2,
#  "b'fhéidir-b'fhéidir": 1,
#  'seo-seo': 7,
#  'fear-lúfar': 1,
#  'ní-ní': 9,
#  'leithead-leithead': 1,
#  'scealpaigh-scealpaigh': 1,
#  'annseo-anseo': 2,
#  'ach-ach': 8,
#  'smaointiughadh-smaoineamh': 1,
#  'cumhangas-chúngas': 1,
#  'coise-coise': 3,
#  'taoibh-taobh': 3,
#  'thall-thall': 3,
#  'taobh-taobh': 1,
#  'amuigh-amuigh': 2,
#  'chroidhe-chroí': 1,
#  'bualadh-bualadh': 1,
#  'thaoibh-thaobh': 1,
#  'beinne-binne': 1,
#  'éirghe-éirí': 2,
#  'amháin-amháin': 4,
#  'iongantach-iontach': 1,
#  'contabhair-contúirteach': 1,
#  'nuair-fuair': 1,
#  'caithfidh-caithfidh': 3,
#  'éagcosamhail-éagosúil': 1,
#  'seán-sean': 2,
#  'méid-méid': 2,
#  ':-:': 2,
#  'chuma-chuma': 1,
#  'dtaobh-dtaobh': 1,
#  'chualaidh-chuala': 2,
#  'tormán-tormán': 1,
#  'cos-cos': 1,
#  'bhris-bhris': 1,
#  'port-port': 1,
#  'feadalaighe-feadalaí': 1,
#  'tsuaimh-tsuaimhneas': 1,
#  'é-é': 2,
#  'fonn-fonn': 1,
#  'scairtigh-scairtigh': 1,
#  'fanacht-fanacht': 1,
#  'gcúl-gcúl': 1,
#  'ábalta-ábalta': 3,
#  "d'éirigh-d'éirigh": 2,
#  'fhánaidh-fhána': 1,
#  'righte-rite': 2,
#  'tobann-tobann': 1,
#  'dtí-dtí': 2,
#  'sí-sí': 1,
#  'chaoin-chaoin': 1,
#  'sinn-sinn': 1,
#  'araon-araon': 1,
#  'h-árd-hard': 1,
#  'mhéad-mhéad': 1,
#  'aindeóin-ainneoin': 2,
#  'mise-mise': 3,
#  'dhá-dhá': 3,
#  'thaibhleadh-tháibhle': 1,
#  'briseadh-briseadh': 1,
#  'scéal-scéal': 1,
#  'éamoinn-éamainn': 1,
#  'ó-ó': 3,
#  'cionn-ceann': 1,
#  'tamaill-tamaill': 1,
#  'bhéidh-bheidh': 1,
#  'baint-baint': 1,
#  'againn-againn': 1,
#  'cineál-cineál': 2,
#  'bith-bith': 3,
#  'tuarascbháil-tuarascáil': 1,
#  'sheáin-sheáin': 1,
#  'dóigh-dóigh': 3,
#  'ndeachaidh-ndeachaigh': 1,
#  'aige-aige': 1,
#  'h-é-hé': 1,
#  'bheó-bheo': 1,
#  'shábháil-shábháil': 1,
#  'shláinte-shláinte': 1,
#  'mhisneach-mhisneach': 1,
#  'choinneáil-choinneáil': 1,
#  '---': 2,
#  'lean-lean': 1,
#  "do'n-den": 1,
#  'iascaireacht-iascaireacht': 1,
#  'feadh-feadh': 1,
#  'tuirseach-tuirseach': 1,
#  "de'n-den": 2,
#  'obair-obair': 1,
#  'smaointigh-smaoinigh': 1,
#  'fhéad-fhéad': 1,
#  'beanna-beanna': 1,
#  'atá-atá': 1,
#  'thoir-thoir': 1,
#  'de-den': 1,
#  'uair-uair': 3,
#  'dheireannach-dheireanach': 1,
#  'beannaibh-beanna': 1,
#  'casadh-casadh': 1,
#  'gáige-gáige': 1,
#  'uchtach-uchtach': 1,
#  'léimint-léimint': 1,
#  'faitchíos-faitíos': 1,
#  'mbéinn-mbeinn': 1,
#  'theacht-theacht': 1,
#  'bhliadhain-bhliain': 2,
#  'thárla-tharla': 1,
#  'fheiceáil-fheiceáil': 1,
#  'cuma-cuma': 2,
#  'comh-chomh': 2,
#  'h-uathbhásach-huafásach': 1,
#  'shúilibh-shúile': 1,
#  'minic-minic': 1,
#  'chuir-chuir': 3,
#  'inistear-fheinistear': 2,
#  'h-amharc-hamharc': 1,
#  'air-air': 2,
#  'aon-aon': 1,
#  'duine-duine': 2,
#  'mbád-mbád': 1,
#  'sean-iascaire-seaniascaire': 1,
#  'de-de': 5,
#  'chuid-chuid': 2,
#  'n-oileán-n-oileán': 1,
#  "d'innis-d'inis": 1,
#  'damh-domh': 2,
#  'béal-béal': 1,
#  'uaimhe-uaimhe': 1,
#  'leóga-leoga': 2,
#  'doiligh-doiligh': 1,
#  'thuigbheáil-thuigbheáil': 1,
#  'dubhairt-dúirt': 3,
#  'fosta-fosta': 1,
#  'cúroí-cúroí': 1,
#  'lúthmhar-lúfar': 1,
#  'baraille-bairille': 2,
#  'rum-rum': 1,
#  'faoi-faoi': 1,
#  'gach-gach': 1,
#  'ascail-ascaill': 1,
#  'léim-léim': 3,
#  'bhórd-bhord': 1,
#  'magamhail-magúil': 1,
#  'ghaisceamhlacht-ghaisciúlacht': 1,
#  'tsean-talltóra-tseantalltóra': 1,
#  'cuid-cuid': 1,
#  'mhór-mhór': 1,
#  "b'ísle-b'ísle": 1,
#  'ná-ná': 2,
#  'gcaithfeadh-gcaithfeadh': 1,
#  'chonnaic-chonaic': 1,
#  'mhillteanach-mhillteanach': 1,
#  'innte-inti': 1,
#  'chor-chor': 1,
#  'droch-mheas-drochmheas': 1,
#  'chladhaireacht-chlaidhreacht': 1,
#  'aroimhe-roimhe': 1,
#  'cruthuighthe-cruthaithe': 1,
#  'díoghbháil-díobháil': 1,
#  'calmacht-calmachta': 1,
#  'rinne-rinne': 1,
#  'ndéanfainn-ndéanfainn': 1,
#  'níos-níos': 1,
#  'chuartughadh-chuartú': 1,
#  "b'óige-b'óige": 1,
#  "b'fheárr-b'fhearr": 1,
#  'gearradh-gearradh': 1,
#  'léim-léime': 1,
#  'éadtrom-éadrom': 1,
#  'chinneamhaint-chinniúint': 1,
#  'chionn-chionn': 1,
#  'bhroslughadh-bhroslú': 1,
#  'un-chun': 1,
#  'tosaigh-tosaigh': 1,
#  'gurbh-gurbh': 1,
#  'fhiú-fhiú': 1,
#  'cuartughadh-cuartú': 1,
#  't-amharc-t-amharc': 1,
#  'céadna-céanna': 1,
#  'bheinn-bhinn': 1,
#  "ó'n-ón": 2,
#  'uirthe-uirthi': 2,
#  'fhairrge-fharraige': 1,
#  'múr-múr': 1,
#  'charraic-charraig': 1,
#  'shleamhain-shleamhain': 2,
#  'phill-phill': 1,
#  'seal-seal': 2,
#  'dreapadaigh-dreapadaigh': 1,
#  'coisidheacht-coisíocht': 1,
#  'míle-míle': 1,
#  'díom-díom': 1,
#  'gan-gan': 1,
#  'thiar-thiar': 1,
#  'ghnáthach-ghnách': 1,
#  'shaoilstin-shílstin': 1,
#  'sháith-sháith': 1,
#  'déanamh-déanamh': 1,
#  'talltóir-talltóir': 1,
#  'thabhairt-thabhairt': 1,
#  'pholl-pholl': 1,
#  'chosamhlacht-chosúlacht': 1,
#  'fuinneóige-fuinneoige': 1,
#  'táirseach-tairseach': 1,
#  'sleamhain-sleamhain': 1,
#  'comhthrom-cothrom': 1,
#  'cuid-chuid': 1,
#  'eile-eile': 1,
#  'garbh-garbh': 1,
#  'ghrian-ghrian': 1,
#  'ndiaidh-ndiaidh': 1,
#  'bun-bun': 1,
#  'slaite-slaite': 1,
#  "d'athain-d'aithin": 1,
#  'táirsigh-tairseach': 1,
#  'dréim-dréim': 1,
#  'dornán-cionn': 1,
#  'facilis-facilis': 1,
#  'descensus-descensus': 1,
#  'arsa-arsa': 1,
#  'fágadh-fágadh': 1,
#  'bomaite-bomaite': 1,
#  'chosaibh-chosa': 1,
#  'las-las': 1,
#  'cipín-cipín': 1,
#  'solais-solais': 1}

# %%
target_text[0:10]
# Out:
# ['cinnte go leor , thiocfadh dóibh bás a fháil ar imeall an phoill úd .',
#  'bhí sé follasach go raibh an poll sin ag foscladh ar an fharraige ar dhóigh éigin , nó líonadh agus thráigheadh an t-uisce ann .',
#  "d'fhéadfadh siad bás a fháil ar a bhruach agus na coirp a imeacht ar an lán mhara amach fríd an phluais .",
#  "thiocfadh dóibh fosta lámh a chur ina mbás féin , a ghabháil de léim isteach sa pholl ghalach a bhí in iarthar an dara táibhle - poll mar a bheadh coire d'uisce ghalach ann .",
#  'ina dhiaidh sin bhí rud éigin dochreidte agus leamh i ngach teoiric den bheirt .',
#  'nuair a scríobh siad an litir sin bhí siad araon i sláinte mhaith agus tréan bídh acu .',
#  'bhí a fhios againn i gceart nach raibh díobháil ar bith orthu , nó diomaite de chuid bonnóg chathail tháinig muid ar an áit taiscthe a bhí acu - scealpach bheag eadar dhá charraig - agus arán agus spólaí de chaoireoil shaillte ann .',
#  "b'fhurasta a fheiceáil cá dtáinig an chaoireoil .",
#  'ar urlár na huaimhe bhí cnámha caorach ar gearradh an fheoil anuas díobh .',
#  'is éard ab éigean don chaora a ghabháil le binn agus titim fríd an sceilp anuas san uaimh .']

# %%
source_to_target_frequencies
# Out:
# {'cinnte-cinnte': 217,
#  'go-go': 7889,
#  'leór-leor': 151,
#  ',-,': 17002,
#  'thiocfadh-thiocfadh': 324,
#  'dóbhtha-dóibh': 33,
#  'bás-bás': 172,
#  'a-a': 23483,
#  'fhagháil-fháil': 175,
#  'ar-ar': 12978,
#  'imeall-imeall': 28,
#  'an-an': 22152,
#  'phuill-phoill': 6,
#  '.-.': 22853,
#  'bhruach-bhruach': 46,
#  'agus-agus': 15390,
#  'na-na': 7089,
#  'cuirp-coirp': 11,
#  'fosta-fosta': 253,
#  'lámh-lámh': 256,
#  'chur-chur': 474,
#  'ina-ina': 795,
#  'mbás-mbás': 5,
#  'féin-féin': 2415,
#  'ghabháil-ghabháil': 85,
#  'de-de': 2165,
#  'léim-léim': 137,
#  'isteach-isteach': 888,
#  'sa-sa': 892,
#  'pholl-pholl': 38,
#  'ghalach-ghalach': 2,
#  'bhí-bhí': 10906,
#  'n-iarthar-iarthar': 4,
#  'dara-dara': 225,
#  'taibhlidh-táibhle': 2,
#  '---': 573,
#  'poll-poll': 47,
#  'mar-mar': 1622,
#  "uisce-d'uisce": 1,
#  'ann-ann': 1800,
#  'na-ina': 741,
#  'dhiaidh-dhiaidh': 491,
#  'sin-sin': 4001,
#  'nuair-nuair': 2046,
#  'scríobh-scríobh': 25,
#  'siad-siad': 2378,
#  'litir-litir': 36,
#  'araon-araon': 31,
#  'i-i': 4132,
#  'sláinte-sláinte': 21,
#  'mhaith-mhaith': 414,
#  'tréan-tréan': 34,
#  'bidh-bídh': 13,
#  'aca-acu': 645,
#  "b'fhuras-b'fhurasta": 3,
#  'fheiceáil-fheiceáil': 74,
#  'cá-cá': 211,
#  'dtáinig-dtáinig': 193,
#  'chaoir-fheóil-chaoireoil': 1,
#  'urlár-urlár': 94,
#  'h-uaimhe-huaimhe': 40,
#  'cnámha-cnámha': 22,
#  'caorach-caorach': 39,
#  'gearradh-gearradh': 23,
#  'fheóil-fheoil': 10,
#  'anuas-anuas': 244,
#  'díobhtha-díobh': 20,
#  'níor-níor': 1044,
#  'bhac-bhac': 14,
#  'muid-muid': 394,
#  'leis-leis': 2593,
#  'taiscidh-taisce': 4,
#  'deimhin-deimhin': 2,
#  'is-is': 1537,
#  'mó-mó': 133,
#  'mhéaduigh-mhéadaigh': 20,
#  'í-í': 1003,
#  'ann-an': 17,
#  "d'fhág-d'fhág": 273,
#  'mé-mé': 4379,
#  'corn-corn': 8,
#  'bhrandai-bhrandaí': 1,
#  'cailleadh-cailleadh': 37,
#  'ndearbhráithreach-ndeartháireacha': 3,
#  'scéal-scéal': 232,
#  'comh-chomh': 738,
#  'h-iongantach-hiontach': 23,
#  'h-éagsamhalta-héagsúlta': 1,
#  'nach-nach': 1994,
#  'mbéadh-mbeadh': 356,
#  'iongantas-iontas': 134,
#  'orm-orm': 623,
#  'ba-ba': 1948,
#  'chuma-chuma': 111,
#  'caidé-cad': 200,
#  'dheireadh-dheireadh': 181,
#  'thart-thart': 795,
#  'liom-liom': 863,
#  'rud-rud': 859,
#  'bith-bith': 1600,
#  'chreidbheáil-chreidbheáil': 6,
#  'anois-anois': 708,
#  'láthair-láthair': 130,
#  'cháis-chais': 1,
#  'dhiamhraigh-dhiamhraigh': 1,
#  'seo-seo': 1452,
#  'ní-ní': 4307,
#  'bhodhróchaidh-bhodhróchaidh': 1,
#  'thú-thú': 174,
#  'ag-ag': 7694,
#  'tabhairt-tabhairt': 144,
#  'cunntais-cuntais': 1,
#  'ár-ár': 185,
#  'gcuid-gcuid': 233,
#  'comhairleacha-comhairleacha': 5,
#  'teóir-teoiricí': 1,
#  'baramhlacha-barúlacha': 6,
#  'gur-gur': 1553,
#  'chaith-chaith': 329,
#  'sé-sé': 8898,
#  'nó-nó': 1387,
#  'seacht-seacht': 98,
#  'gabháil-gabháil': 239,
#  'síos-síos': 514,
#  'dúinn-dúinn': 127,
#  'san-san': 313,
#  'am-am': 283,
#  'coimhthiolán-comhthionól': 3,
#  'mór-mór': 834,
#  'daoine-daoine': 209,
#  'cruinn-cruinn': 69,
#  'fá-fá': 970,
#  'shleas-shleas': 1,
#  'chnuic-chnoic': 57,
#  'freeman-freeman': 12,
#  'bhean-bhean': 246,
#  'somhairle-somhairle': 6,
#  'cathal-cathal': 53,
#  'beag-beag': 644,
#  'measc-measc': 10,
#  'mise-mise': 625,
#  'duine-duine': 1104,
#  'dheireannach-dheireanach': 35,
#  'tháinig-tháinig': 1711,
#  'aníos-aníos': 213,
#  'súil-súil': 129,
#  'agam-agam': 715,
#  'shiubhal-shiúl': 241,
#  'sul-sula': 173,
#  'dhéanfaidh-dhéanfaidh': 14,
#  'dearmad-dearmad': 112,
#  'choidhche-choíche': 44,
#  "de'n-den": 670,
#  'dreach-dreach': 54,
#  'athair-athair': 83,
#  'mháthair-mháthair': 313,
#  "d'aithris-d'aithris": 5,
#  'duibhleannach-duibhleannach': 1,
#  'chuaidh-chuaigh': 1555,
#  'leas-oifigeach-leasoifigeach': 1,
#  'arís-arís': 326,
#  'fear-fear': 1407,
#  'chuir-chuir': 1233,
#  'tús-tús': 85,
#  'dhearbhráthair-dheartháir': 15,
#  'leigeadh-ligeadh': 34,
#  'ceachtar-ceachtar': 48,
#  'thug-thug': 1180,
#  'fríd-fríd': 227,
#  'uaimh-uaimh': 55,
#  'uilig-uilig': 395,
#  'thaisbeáin-thaispeáin': 21,
#  "acha'n-gach": 11,
#  "b'ion-b'iontach": 1,
#  'aghaidh-aghaidh': 231,
#  'bán-bán': 126,
#  'teannta-teannta': 11,
#  'ach-ach': 1754,
#  'rabh-raibh': 3584,
#  'comhartha-comhartha': 40,
#  'bróin-bróin': 7,
#  'le-le': 3393,
#  'air-air': 2110,
#  'glór-glór': 93,
#  'chinn-chinn': 115,
#  'íseal-íseal': 47,
#  'suaimhneach-suaimhneach': 61,
#  'labhaireadh-labhradh': 4,
#  'dhath-dhath': 233,
#  'úr-úr': 118,
#  'feiceáil-feiceáil': 91,
#  'baint-baint': 129,
#  'as-as': 1378,
#  'dhorcha-dhorcha': 23,
#  'uachtar-uachtar': 24,
#  'scaradh-scaradh': 11,
#  'bunadh-bunadh': 66,
#  'fuair-fuair': 663,
#  'greim-greim': 213,
#  'casóige-casóige': 1,
#  'tá-tá': 2067,
#  'lúthgháir-lúcháir': 88,
#  'fhág-fhág': 101,
#  'tú-tú': 1013,
#  'neithe-nithe': 7,
#  'bhíthear-bhíothas': 51,
#  'á-á': 128,
#  'duit-duit': 250,
#  'bhfuil-bhfuil': 1014,
#  'beó-beo': 105,
#  'annsin-ansin': 1451,
#  'fóill-fóill': 210,
#  'táthar-táthar': 13,
#  'roda-ruda': 3,
#  'chéadna-chéanna': 148,
#  'damh-sa-domhsa': 30,
#  'baineadh-baineadh': 85,
#  'stangadh-stangadh': 8,
#  'asam-asam': 33,
#  'innis-inis': 54,
#  'damh-domh': 319,
#  'mura-mura': 7,
#  'choinne-choinne': 185,
#  't-arán-t-arán': 9,
#  'bhrandaí-bhrandaí': 3,
#  'scealpaigh-scealpaigh': 6,
#  'cad-cad': 103,
#  'chuige-chuige': 236,
#  'iad-iad': 776,
#  'ceart-ceart': 100,
#  'ghasúr-ghasúr': 83,
#  'cheana-cheana': 37,
#  "mb'fhéidir-mb'fhéidir": 43,
#  'iarraidh-iarraidh': 389,
#  '?-?': 1145,
#  "d'amharc-d'amharc": 296,
#  'ath-uair-athuair': 20,
#  'sheasamh-sheasamh': 123,
#  'áit-áit': 511,
#  'amharc-amharc': 353,
#  'mhuinntear-mhuintir': 8,
#  'giota-giota': 94,
#  'taca-taca': 35,
#  'gol-gol': 16,
#  'bhéarfaidh-bhéarfaidh': 39,
#  'eile-eile': 1197,
#  'chathail-chathail': 14,
#  'arsa-arsa': 1780,
#  'chroith-chroith': 39,
#  'sásta-sásta': 94,
#  "d'imthigh-d'imigh": 410,
#  'rith-rith': 164,
#  'ndiaidh-ndiaidh': 502,
#  'bhunaidh-bhunaidh': 2,
#  'beódhacht-beocht': 5,
#  'soilbhreacht-soilbhreacht': 1,
#  'naoidheanán-naíonán': 11,
#  'leanbán-leanbán': 1,
#  'shiubhail-shiúil': 202,
#  'un-chun': 325,
#  'bhaile-bhaile': 676,
#  'eadar-eadar': 233,
#  "a's-agus": 64,
#  'ó-ó': 1521,
#  'sholas-sholas': 12,
#  'tráthnóna-tráthnóna': 286,
#  'céadna-céanna': 124,
#  'tamall-tamall': 226,
#  'comhráidh-comhrá': 18,
#  'aistidheach-aisteach': 24,
#  'dtugann-dtugann': 23,
#  'spaisteóracht-spaisteoireacht': 11,
#  'cabhsa-cabhsa': 14,
#  'n-aice-aice': 69,
#  'theach-theach': 114,
#  'cúpla-cúpla': 28,
#  'péire-péire': 52,
#  'coinín-coiníní': 1,
#  'istigh-istigh': 16,
#  'rópa-ropa': 11,
#  'ghualainn-ghualainn': 48,
#  'gallach-gallach': 2,
#  'luin-lón': 1,
#  'smaolaigh-smólach': 1,
#  'brath-brath': 81,
#  'siubhal-siúl': 141,
#  'mé-é': 14,
#  'labhaireann-labhrann': 3,
#  'shomhairle-shomhairle': 2,
#  'leat-leat': 331,
#  'scaifte-scaifte': 51,
#  'maidin-maidin': 199,
#  'indiú-inniu': 5,
#  'seisean-seisean': 640,
#  'fhiafruigh-fhiafraigh': 4,
#  'díom-sa-díomsa': 6,
#  'rachainn-rachainn': 18,
#  'bhal-bhail': 33,
#  'brón-brón': 16,
#  'cosamhlacht-cosúlacht': 23,
#  'thaitin-thaitin': 33,
#  'fhreagra-fhreagra': 6,
#  'shaoilim-shílim': 1,
#  'dtéidhim-dtéim': 1,
#  'adhbhar-ábhar': 13,
#  'saoilim-sílim': 11,
#  'bhfuil-bhfuilimid': 4,
#  'bhéas-bheas': 71,
#  'tursach-tuirseach': 1,
#  'tiocfaidh-tiocfaidh': 21,
#  'níl-níl': 262,
#  'h-eólach-heolach': 3,
#  'ortha-orthu': 340,
#  'liom-sa-liomsa': 75,
#  'bheirt-bheirt': 224,
#  'bharr-bharr': 24,
#  'gaoithe-gaoithe': 69,
#  'níorbh-níorbh': 126,
#  'fheasach-fheasach': 4,
#  'oiread-oiread': 214,
#  'cainnte-cainte': 77,
#  'chéile-chéile': 522,
#  'ariamh-riamh': 587,
#  'roimhe-roimhe': 240,
#  'sheasuigh-sheasaigh': 196,
#  'labhair-labhair': 218,
#  'tuairim-tuairim': 45,
#  'bharamhail-bharúil': 97,
#  'tarngaire-tairngire': 1,
#  'fáidh-fáidh': 1,
#  'éigin-éigin': 85,
#  'tseórt-tseort': 6,
#  'chathal-chathal': 10,
#  'cuir-cuir': 51,
#  'scéala-scéala': 37,
#  'chugam-chugam': 66,
#  'cheann-cheann': 432,
#  'tamaill-tamaill': 122,
#  'bhearnaigh-bhearna': 1,
#  'sconnsa-sconsa': 1,
#  'trasna-trasna': 179,
#  'aithghiorra-aicearra': 1,
#  'shuidh-shuigh': 244,
#  'lá-lá': 1183,
#  'geal-geal': 65,
#  'ceithre-ceithre': 83,
#  'h-uaire-huaire': 37,
#  'deireannacha-deireanacha': 11,
#  'caithte-caite': 79,
#  'scríobhadh-scríobh': 13,
#  'trácht-tráchta': 1,
#  'oifigeamhail-oifigiúil': 4,
#  'cheann-chinn': 1,
#  'phríobh-phríobháidigh': 1,
#  'beannacht-beannacht': 12,
#  'chugat-chugat': 23,
#  'watkins-watkins': 8,
#  '(-(': 75,
#  ')-)': 56,
#  'fáighte-faighte': 4,
#  '!-!': 1027,
#  '23-23': 1,
#  'nodlaig-nollag': 2,
#  'theacht-theacht': 160,
#  'dhiamhrach-dhiamhrach': 1,
#  'chuartughadh-chuartú': 33,
#  'bonnógaí-bonnóga': 1,
#  'mallaibh-mallaibh': 14,
#  'leagadh-leagadh': 13,
#  'méar-mear': 7,
#  'rudaí-rudaí': 72,
#  'sceilp-sceilp': 6,
#  'chonnaic-chonaic': 401,
#  'rón-rón': 37,
#  'gceann-gceann': 77,
#  'puill-poill': 4,
#  'tchím-tím': 21,
#  'chuig-chuig': 185,
#  'fhear-fhear': 416,
#  '24-24': 4,
#  'h-uair-huair': 59,
#  'bascaid-bascaeid': 1,
#  'aráin-aráin': 52,
#  'foscailte-foscailte': 16,
#  'cuid-cuid': 491,
#  'dá-dá': 1057,
#  'innte-inti': 62,
#  'ithte-ite': 15,
#  'tugtha-tugtha': 36,
#  'tuairisc-tuairisc': 3,
#  'dearbhráithreacha-deartháireacha': 3,
#  "m'inchinn-m'inchinn": 3,
#  'mearughadh-mearú': 1,
#  'fir-fir': 364,
#  'buaidhreadh-buaireamh': 40,
#  'intinne-intinne': 24,
#  'millteanach-millteanach': 38,
#  'hanraí-hanraí': 2,
#  'reachtáil-reáchtáil': 21,
#  'cluinim-cluinim': 11,
#  'scairtigh-scairtigh': 12,
#  's-s': 17,
#  'w-w': 1,
#  'grásta-grásta': 13,
#  'dé-dé': 92,
#  'chan-chan': 157,
#  'eagnaidheacht-eagnaíocht': 3,
#  'dhaonna-dhaonna': 2,
#  'shábháil-tharrtháil': 1,
#  'agus-as': 10,
#  'minic-minic': 193,
#  'dubhairt-dúirt': 474,
#  "m'athair-m'athair": 70,
#  'creidte-creidte': 7,
#  'seán-sean': 64,
#  'péas-péas': 35,
#  'gárdaí-gardaí': 12,
#  'chósta-chósta': 8,
#  'dall-dall': 8,
#  'gnoithí-gnoithe': 1,
#  'fiú-fiú': 61,
#  'bleachtaire-bleachtaire': 1,
#  'iomráidhteach-iomráiteach': 4,
#  'baile-baile': 155,
#  'átha-átha': 87,
#  'cliath-cliath': 92,
#  'bhreathnughadh-bhreathnú': 11,
#  'eólais-eolais': 12,
#  'deireadh-deireadh': 341,
#  'amach-amach': 1448,
#  'mbraigh-mbraighdeanas': 2,
#  'amháin-amháin': 741,
#  'ndéanfaidh-ndéanfaidh': 6,
#  'bráthach-brách': 18,
#  'roimh-roimh': 128,
#  'bricfeasta-bricfeasta': 7,
#  'dtárlóchadh-dtarlóchadh': 1,
#  'dtiocfadh-dtiocfadh': 181,
#  'léas-leas': 4,
#  'feasa-feasa': 7,
#  'mo-mo': 1436,
#  'dtéidhinn-dtéinn': 2,
#  'dubh-charraic-dúcharraig': 4,
#  "dh'iascaireacht-dh'iascaireacht": 3,
#  'bhínn-bhínn': 12,
#  'scaoileadh-scaoileadh': 10,
#  'bogha-bogha': 3,
#  'chaillinn-chaillinn': 1,
#  'saghad-saighead': 2,
#  'gnáthach-ghnách': 2,
#  'é-mé': 17,
#  'thabhairt-thuairim': 1,
#  'é-é': 3212,
#  'chur-chuir': 5,
#  'bheart-bheart': 3,
#  'tí-tí': 11,
#  'ngníomh-ngníomh': 4,
#  'leig-lig': 244,
#  'aon-haon': 17,
#  'shlat-shlat': 5,
#  'tarraingt-tarraingt': 200,
#  'ruaim-ruaim': 7,
#  "dh'iascair-dh'iascaireacht": 1,
#  "b'fhéidir-b'fhéidir": 283,
#  'iasc-iasc': 12,
#  'gan-gan': 1040,
#  'aiste-aiste': 7,
#  'déanamh-déanamh': 253,
#  'féachfaidh-féachfaidh': 2,
#  'carraic-carraig': 4,
#  'aon-aon': 695,
#  'thaoibh-thaobh': 113,
#  'láimhe-láimhe': 80,
#  'deise-deise': 48,
#  'aill-aill': 1,
#  'árd-ard': 95,
#  'féachaim-féachaim': 1,
#  'taobh-taobh': 313,
#  'clí-clé': 12,
#  'streachail-streachail': 10,
#  'faragáin-fargáin': 1,
#  'fad-fad': 170,
#  'dhomhain-dhomhain': 5,
#  'dtaoibh-dtaobh': 12,
#  'beinne-binne': 39,
#  'sí-sí': 3028,
#  'tuitim-titim': 109,
#  'díreach-díreach': 326,
#  'fairrge-farraige': 62,
#  'leóga-leoga': 34,
#  'gág-gág': 3,
#  'scáthmhar-scáfar': 11,
#  't-uisce-t-uisce': 28,
#  'munamar-monabhar': 14,
#  'dorranda-dorránach': 1,
#  'bun-bun': 103,
#  'chuartuigh-chuartaigh': 33,
#  'lorg-lorg': 82,
#  'sheáin-sheáin': 45,
#  'rinne-rinne': 949,
#  'bád-bád': 130,
#  'chéaslóracht-chéaslóireacht': 1,
#  'fríthe-fríthi': 14,
#  'ceann-ceann': 435,
#  'ró-chumang-róchúng': 1,
#  'iomartha-iomartha': 3,
#  'pilleadh-pilleadh': 43,
#  'n-a-lena': 65,
#  'glanadh-glanadh': 8,
#  'fear-lúfar': 1,
#  'leithead-leithead': 20,
#  'annseo-anseo': 291,
#  'smaointiughadh-smaoineamh': 14,
#  'cumhangas-chúngas': 1,
#  'coise-coise': 17,
#  'taoibh-taobh': 179,
#  'thall-thall': 178,
#  'amuigh-amuigh': 386,
#  'theann-theann': 37,
#  'tslait-tslat': 4,
#  'láimh-láimh': 95,
#  'chroidhe-chroí': 185,
#  'nár-nár': 404,
#  'shleamhain-shleamhain': 14,
#  'chos-chos': 35,
#  'fhachair-fhothair': 5,
#  'chumhang-chúng': 6,
#  'bhuail-bhuail': 255,
#  'bualadh-bualadh': 46,
#  'éirghe-éirí': 224,
#  'iongantach-iontach': 163,
#  'contabhair-contúirteach': 1,
#  'nuair-fuair': 2,
#  'tslighe-tslí': 6,
#  'chnapánach-chnapánach': 2,
#  'fiar-fiar': 12,
#  'suas-suas': 486,
#  'giall-giall': 14,
#  ';-;': 1000,
#  'h-áit-háit': 28,
#  'in-shiubhalta-insiúlta': 2,
#  'cumhang-cúng': 5,
#  'má-má': 432,
#  'bheinn-bhinn': 36,
#  'gheobhainn-gheobhainn': 10,
#  'bheó-bheo': 13,
#  'mharbh-mharbh': 15,
#  'bhfad-bhfad': 282,
#  'bunadhas-bunús': 26,
#  'míle-míle': 88,
#  'n-éadan-éadan': 26,
#  'dtug-dtug': 78,
#  'dear-dear': 166,
#  'aroimhe-roimhe': 42,
#  'caithfidh-caithfidh': 102,
#  'éagcosamhail-éagosúil': 4,
#  'méid-méid': 136,
#  ':-:': 330,
#  'dtaobh-dtaobh': 83,
#  'mbéal-mbéal': 72,
#  'dóchas-dóchas': 32,
#  'eagla-eagla': 300,
#  'coipiughadh-coipeadh': 1,
#  'dtí-dtí': 594,
#  'ábalta-ábalta': 120,
#  'scairt-scairt': 30,
#  'dhéanamh-dhéanamh': 346,
#  'fada-fada': 267,
#  'buan-buan': 25,
#  'ionnam-ionam': 32,
#  'bogadh-bogadh': 45,
#  'chualaidh-chuala': 183,
#  'tormán-tormán': 70,
#  'cos-cos': 59,
#  'bhris-bhris': 99,
#  'port-port': 45,
#  'feadalaighe-feadalaí': 13,
#  'tsuaimh-tsuaimhneas': 1,
#  'fonn-fonn': 53,
#  'thaidhbhse-thaibhse': 2,
#  'rómham-romham': 13,
#  'fánaidh-fána': 11,
#  'throm-throm': 24,
#  'béic-béic': 11,
#  'siud-siúd': 37,
#  'fhánaidh-fhána': 15,
#  'fanacht-fanacht': 124,
#  'gcúl-gcúl': 96,
#  "d'éirigh-d'éirigh": 480,
#  'righte-rite': 19,
#  'tobann-tobann': 62,
#  'sciorr-sciorr': 2,
#  'thuit-thit': 202,
#  'bhog-bog': 1,
#  'h-ionfairteadh-únfairteadh': 1,
#  'chosaibh-chosa': 9,
#  'mbomaite-mbomaite': 10,
#  'snadhmtha-snaidhmthe': 1,
#  'chaoin-chaoin': 40,
#  'sinn-sinn': 79,
#  'h-árd-hard': 28,
#  'mhéad-mhéad': 45,
#  'scor-scor': 85,
#  'againn-againn': 268,
#  'labhairt-labhairt': 87,
#  'fhada-fhada': 95,
#  'chugainn-chugainn': 73,
#  'dhúithche-dhúiche': 4,
#  'thús-thús': 45,
#  "d'innis-d'inis": 182,
#  'gach-gach': 273,
#  "da'r-dar": 1,
#  'thárla-tharla': 86,
#  'aindeóin-ainneoin': 20,
#  'cur-cur': 370,
#  'iongantais-iontais': 45,
#  'aitis-aitis': 2,
#  'rónta-rónta': 17,
#  'chlóidh-chlóigh': 1,
#  'teine-tine': 71,
#  'dorchadas-dorchadas': 57,
#  'scáilí-scáilí': 2,
#  'ruagadh-ruagadh': 2,
#  'ballaí-ballaí': 45,
#  'creagach-creagacha': 1,
#  'gríobháin-gríobháin': 1,
#  'chasta-chasta': 6,
#  'mbíodh-mbíodh': 228,
#  'macalla-macalla': 13,
#  'éagchaoin-éagaoin': 1,
#  'dhá-dhá': 555,
#  'thaibhleadh-tháibhle': 1,
#  'briseadh-briseadh': 80,
#  'éamoinn-éamainn': 8,
#  'iomlán-hiomlán': 3,
#  'mion-rudaí-mionrudaí': 2,
#  'bhaineas-bhaineann': 1,
#  'réidhteach-réiteach': 19,
#  'caithfidh-caithfimid': 4,
#  'arais-ais': 35,
#  'scéil-scéil': 21,
#  'freeman-sean': 1,
#  'gcurtha-gcora': 1,
#  'léightheóra-léitheora': 1,
#  'críoch-críoch': 7,
#  'rún-rún': 70,
#  'cionn-ceann': 59,
#  'bhéidh-bheidh': 57,
#  'cineál-cineál': 107,
#  'tuarascbháil-tuarascáil': 1,
#  'dóigh-dóigh': 312,
#  'ndeachaidh-ndeachaigh': 25,
#  'aige-aige': 1187,
#  'h-é-hé': 29,
#  'shábháil-shábháil': 28,
#  'shláinte-shláinte': 9,
#  'mhisneach-mhisneach': 2,
#  'choinneáil-choinneáil': 97,
#  'leath-leath': 100,
#  'trí-trí': 221,
#  'bhain-bhain': 332,
#  'iascaireacht-iascaireacht': 6,
#  'bruideadh-broideadh': 1,
#  'díom-díom': 50,
#  'líneán-líonán': 1,
#  'garbhánach-garbhánach': 3,
#  'cupla-cúpla': 5,
#  'cósta-cósta': 3,
#  'forrán-forrán': 7,
#  'lean-lean': 65,
#  "do'n-den": 15,
#  'feadh-feadh': 173,
#  'tuirseach-tuirseach': 74,
#  'obair-obair': 293,
#  'bhéadh-bheadh': 535,
#  'mongaigh-mangaigh': 1,
#  'uair-uair': 386,
#  'éisc-éisc': 5,
#  'spórt-spórt': 5,
#  'n-iascaireacht-n-iascaireacht': 1,
#  'smaointigh-smaoinigh': 26,
#  'fhéad-fhéad': 9,
#  'beanna-beanna': 11,
#  'atá-atá': 777,
#  'thoir-thoir': 60,
#  'de-den': 5,
#  'beannaibh-beanna': 4,
#  'casadh-casadh': 207,
#  'gáige-gáige': 1,
#  'uchtach-uchtach': 50,
#  'léimint-léimint': 2,
#  'faitchíos-faitíos': 4,
#  'mbéinn-mbeinn': 32,
#  'bhliadhain-bhliain': 123,
#  'cuma-cuma': 214,
#  'h-uathbhásach-huafásach': 3,
#  'shúilibh-shúile': 17,
#  'suimeamhail-suimiúil': 2,
#  'ceárnach-cearnach': 2,
#  'cionn-cionn': 152,
#  'láin-láin': 10,
#  'mhara-mhara': 13,
#  'inistear-fheinistear': 3,
#  'h-amharc-hamharc': 8,
#  'mbád-mbád': 9,
#  'sean-iascaire-seaniascaire': 2,
#  'chuid-chuid': 778,
#  'n-oileán-n-oileán': 9,
#  'béal-béal': 107,
#  'uaimhe-uaimhe': 1,
#  'doiligh-doiligh': 59,
#  'thuigbheáil-thuigbheáil': 6,
#  'fuinneóg-fuinneog': 15,
#  'chúroí-chúroí': 17,
#  'bheirthí-bheirtí': 1,
#  'talltóir-talltóir': 4,
#  'gcúroí-gcúroí': 1,
#  'cúroí-cúroí': 1,
#  'lúthmhar-lúfar': 10,
#  'baraille-bairille': 4,
#  'rum-rum': 1,
#  'faoi-faoi': 280,
#  'ascail-ascaill': 1,
#  'bhórd-bhord': 13,
#  'magamhail-magúil': 4,
#  'ghaisceamhlacht-ghaisciúlacht': 3,
#  'tsean-talltóra-tseantalltóra': 1,
#  'faisnéis-faisnéis': 3,
#  'n-abóradh-n-abóradh': 1,
#  'shéan-shéan': 1,
#  'dubh-dubh': 176,
#  'dhubhairt-dhúirt': 65,
#  'faobhar-faobhar': 11,
#  'fiafruigheachta-fiafraitheachta': 1,
#  'thíos-thíos': 166,
#  'duibheagán-duibheagán': 4,
#  'gruamdha-gruama': 17,
#  'éagcaoin-éagaoin': 22,
#  'mhór-mhór': 546,
#  "b'ísle-b'ísle": 2,
#  'ná-ná': 745,
#  'gcaithfeadh-gcaithfeadh': 29,
#  'mhillteanach-mhillteanach': 24,
#  'chor-chor': 139,
#  'droch-mheas-drochmheas': 8,
#  'chladhaireacht-chlaidhreacht': 1,
#  'cruthuighthe-cruthaithe': 7,
#  'díoghbháil-díobháil': 21,
#  'calmacht-calmachta': 1,
#  'ndéanfainn-ndéanfainn': 6,
#  'níos-níos': 199,
#  "b'óige-b'óige": 5,
#  "b'fheárr-b'fhearr": 17,
#  'léim-léime': 2,
#  'éadtrom-éadrom': 47,
#  'chinneamhaint-chinniúint': 13,
#  'chionn-chionn': 40,
#  'bhroslughadh-bhroslú': 1,
#  'tosaigh-tosaigh': 123,
#  'gurbh-gurbh': 101,
#  'fhiú-fhiú': 18,
#  'cuartughadh-cuartú': 40,
#  't-amharc-t-amharc': 35,
#  "ó'n-ón": 323,
#  'uirthe-uirthi': 119,
#  'fhairrge-fharraige': 94,
#  'múr-múr': 9,
#  'charraic-charraig': 22,
#  'cuidiughadh-cuidiú': 56,
#  'bheith-bheith': 874,
#  'bhaint-bhaint': 131,
#  'aiste-aisti': 10,
#  'phill-phill': 95,
#  'dheachaidh-dheachaigh': 47,
#  'ghiota-ghiota': 32,
#  'aimhréidhteach-aimhréiteach': 1,
#  'nárbh-nárbh': 52,
#  'fhéidir-fhéidir': 40,
#  'thairis-thairis': 17,
#  'fachair-fothair': 1,
#  'díothbháil-dhíobháil': 1,
#  'cosaibh-cosa': 3,
#  'bior-bior': 5,
#  'iarainn-iarainn': 29,
#  'shlaite-shlaite': 2,
#  'maith-maith': 626,
#  'thar-thar': 137,
#  'chontabhairt-chontúirt': 21,
#  'truisleadh-truisleadh': 3,
#  'h-achrannach-hachrannach': 6,
#  'n-áiteachaibh-áiteacha': 3,
#  'gcaithfinn-gcaithfinn': 9,
#  'cheithre-cheithre': 21,
#  'buinn-boinn': 3,
#  'réir-réir': 131,
#  'seal-seal': 121,
#  'dreapadaigh-dreapadaigh': 1,
#  'coisidheacht-coisíocht': 3,
#  'fadálach-fadálach': 39,
#  'gurbh-gurb': 1,
#  'corr-corr': 11,
#  'cointíneach-cointinneach': 1,
#  'tchífeadh-tífeadh': 8,
#  'gnoitheach-gnoitheach': 13,
#  'bhád-bhád': 61,
#  'cuan-cuan': 11,
#  'dtugamuis-dtugaimis': 2,
#  'linn-linn': 211,
#  'thiar-thiar': 93,
#  "d'athain-d'aithin": 18,
#  'bhomaite-bhomaite': 72,
#  'cruinn-chorrach-cruinnchorrach': 1,
#  'ghnáthach-ghnách': 118,
#  'shaoilstin-shílstin': 1,
#  'sháith-sháith': 84,
#  'thabhairt-thabhairt': 380,
#  'aoirde-airde': 9,
#  "d'fhágadh-d'fhágadh": 13,
#  'chearnach-chearnach': 1,
#  'té-té': 181,
#  'dheas-dheas': 59,
#  'chosamhlacht-chosúlacht': 15,
#  'fuinneóige-fuinneoige': 15,
#  'táirseach-tairseach': 1,
#  'sleamhain-sleamhain': 10,
#  'comhthrom-cothrom': 35,
#  'cuid-chuid': 5,
#  'garbh-garbh': 62,
#  'mín-mín': 47,
#  'imtheacht-imeacht': 234,
#  'bheag-bheag': 248,
#  'táirsigh-tairseach': 7,
#  'ghrian-ghrian': 73,
#  "b'fhiú-fhiú": 12,
#  "b'fhearrde-fhearrde": 1,
#  'dar-dar': 426,
#  'bhfacaidh-bhfaca': 19,
#  'fúm-fúm': 11,
#  'slaite-slaite': 2,
#  'shé-shé': 9,
#  'troighthe-troithe': 9,
#  'fánadh-fána': 5,
#  'chosamhlachta-cosúlachta': 4,
#  'dul-dol': 7,
#  'dréim-dréim': 8,
#  'cá-cár': 11,
#  'ceaptha-ceaptha': 6,
#  'fúni-fúm': 1,
#  'mheadhchoin-mheáchain': 1,
#  'dornán-cionn': 1,
#  'luaithe-luaithe': 60,
#  'chéad-chéad': 282,
#  'shaoil-shíl': 41,
#  'rabhthar-rabhthar': 12,
#  'theilgean-theilgean': 1,
#  'síorruidheachta-síoraíochta': 3,
#  'n-umar-umar': 1,
#  'cruinne-cruinne': 19,
#  'bhog-bhog': 81,
#  'cosamhail-cosúil': 155,
#  'tirim-tirim': 18,
#  'gránadh-gránú': 3,
#  'facilis-facilis': 2,
#  'descensus-descensus': 2,
#  'fágadh-fágadh': 71,
#  'fhuinneóg-fhuinneog': 9,
#  'shamhail-shamhail': 25,
#  'ró-righte-rórite': 1,
#  'tharraingt-tharraingt': 48,
#  'teagmháil-teagmháil': 2,
#  'bomaite-bomaite': 61,
#  'las-las': 26,
#  'cipín-cipín': 7,
#  'solais-solais': 14,
#  'chipín-chipín': 4,
#  'cibé-cibé': 108,
#  'fágtha-fágtha': 74,
#  'gcionn-gceann': 195,
#  'lasóg-lasóg': 14,
#  'ionnta-iontu': 79,
#  'dhóigh-dhóigh': 103,
#  'gasta-gasta': 65,
#  'uaim-uaim': 39,
#  'buna-buna': 2,
#  'philleadh-philleadh': 2,
#  'áibhéiseach-áiféiseach': 1,
#  'chiaróig-chiaróg': 1,
#  'ngaiste-ngaiste': 1,
#  'gloine-ghloine': 8,
#  'gáire-gáire': 120,
#  'choimhéad-choimhéad': 12,
#  'h-uaisle-huaisle': 4,
#  'dubha-dubha': 36,
#  'snámh-snámh': 33,
#  'bhallaibh-bhallaí': 1,
#  'sleamhna-sleamhna': 4,
#  'bpríosúin-bpríosúin': 2,
#  'bhíodh-bhíodh': 346,
#  'seórt-seort': 13,
#  'truaighe-truaighe': 27,
#  'tchínn-tínn': 4,
#  'créatúir-créatúir': 27,
#  'sleamhnughadh-sleamhnú': 8,
#  'leó-leo': 176,
#  'thásc-thasc': 1,
#  'cruaidh-cruaidh': 80,
#  "d'ionnsuigh-d'ionsaigh": 33,
#  'n-áit-áit': 119,
#  'lámha-lámha': 73,
#  'ghlúinibh-ghlúine': 7,
#  'bhfastódh-bhfastó': 3,
#  'scannrughadh-scanradh': 7,
#  'crith-eagla-critheagla': 4,
#  'mhothuigh-mhothaigh': 111,
#  'tocht-tocht': 11,
#  'cruinniughadh-cruinniú': 55,
#  'ndoimhneacht-ndoimhneacht': 8,
#  'nádúire-nádúire': 1,
#  'ruo-rud': 1,
#  'ariamh-roimhe': 5,
#  'bhfuighinn-bhfaighinn': 18,
#  'claonadh-claonadh': 7,
#  'ghabháil-ghabhail': 3,
#  'uillinn-uillinn': 7,
#  'ghairbh-gharbh': 1,
#  "d'fhéach-d'fhéach": 12,
#  'chlí-chlé': 12,
#  'briste-briste': 43,
#  'mothughadh-mothú': 22,
#  'mhéar-mhéar': 21,
#  'dorcha-dorcha': 62,
#  'léir-léir': 47,
#  'dadadh-dada': 78,
#  'thionntuigh-thiontaigh': 131,
#  'bealach-bealach': 193,
#  'chlochaibh-chlocha': 3,
#  'móra-móra': 81,
#  'chnap-chnap': 13,
#  'leathaigh-leathaigh': 6,
#  'luaidh-luaigh': 2,
#  'gágach-gágach': 5,
#  'gar-gar': 78,
#  'gléas-gléas': 35,
#  't-éadóchas-t-éadóchas': 4,
#  'fagháil-fáil': 106,
#  'uachtair-uachtar': 1,
#  "m'intinn-m'intinn": 28,
#  'iomláin-iomláin': 26,
#  'fíochmara-fíochmhara': 1,
#  'ciarógaí-ciaróga': 1,
#  'san-sa': 23,
#  'ghaiste-ghaiste': 11,
#  'ghloine-ghloine': 26,
#  'aindeiseacha-ainniseacha': 2,
#  'thaobhanna-thaobhanna': 2,
#  'dhearna-dhearna': 4,
#  'ró-chosamhail-róchosúil': 2,
#  'chaill-chaill': 79,
#  'sáruigheadh-sáraíodh': 1,
#  'anocht-anocht': 83,
#  "b'éadóiche-éadóiche": 1,
#  'do-do': 1345,
#  'dhia-dhia': 118,
#  'shon-shon': 33,
#  'doimhne-doimhne': 19,
#  'bhreágh-bhreá': 22,
#  'múir-muir': 5,
#  'ribeóg-ribeog': 3,
#  'cheachtar-cheachtar': 6,
#  'mórtas-mórtas': 13,
#  'ngeimhreadh-ngeimhrí': 1,
#  'cartughadh-cartadh': 1,
#  'fosclaidheacha-fosclaíocha': 1,
#  'carraic-carraigeacha': 1,
#  'gurb-gurb': 7,
#  'lár-lár': 159,
#  'mhúir-mhúir': 7,
#  'chnámha-chnámha': 12,
#  'creagachaibh-creagacha': 1,
#  'loitfidhe-loitfí': 1,
#  'charnán-chamán': 2,
#  'shocrughadh-shocrú': 13,
#  'breith-breith': 38,
#  'smaointighthe-smaointe': 3,
#  'líon-líon': 31,
#  'phíopa-phíopa': 54,
#  'phócaí-phócaí': 10,
#  'lasógaí-lasóga': 3,
#  'iomchar-iompar': 40,
#  'scaoilte-scaoilte': 2,
#  'n-iomlán-iomlán': 3,
#  'pócaí-pócaí': 5,
#  'foluighthe-folaithe': 3,
#  'línín-línín': 6,
#  'drod-druidim': 3,
#  'dlúith-dlúth': 13,
#  'mbínn-mbínn': 16,
#  'mhalluighthe-mhallaithe': 6,
#  'solas-solas': 66,
#  'lae-lae': 124,
#  ...}

# %% [markdown]
# ## Noisy Channel Model

# %%
# %%shell
# pip install advertools

# %%
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu

def evaluate(target_words, target_word_index, target_frequencies, source_to_target_frequencies,total_st_frequencies):

  testsource = open('test-source.txt', 'r')
  original = []
  sentence = []
  from_scratch_hypotheses = []
  

  for line in testsource:
    token = line.rstrip("\n").lower()

    if token=='<s>':

      sentence = []

    elif token == '</s>':
      from_scratch_hypotheses.append(predict(sentence,target_words, target_word_index, target_frequencies, source_to_target_frequencies,total_st_frequencies))
      original.append(sentence)
    else:
      sentence.append(token)

    if len(from_scratch_hypotheses) == 100: 
      break

  references = []

  testtarget = open('test-target.txt', 'r')

  x = 0
  # while x > 
  for line in testtarget:
    token = line.rstrip("\n").lower()
    if token=='<s>':
      sentence = []
    elif token == '</s>':
      references.append([sentence])
      # print("Actual",sentence)
      # break
    else: 
      sentence.append(token)
    
    if len(references) == 100: 
      break

  return print((corpus_bleu(references,from_scratch_hypotheses))), from_scratch_hypotheses, references,original

# %%
import advertools as adv
def predict(source_sentence, target_words, target_word_index, target_frequencies, source_to_target_frequencies,total_st_frequencies):  

  target = []

  p_s = [",", "!", "-", ".", "?","'", '"',"á", "na", "liom", "leis", "léi", "'un"]
  stop_punct = list(adv.stopwords["irish"])
  stop_punct = stop_punct + p_s

  total_freqs = sum(target_frequencies.values())

  for ind, val in enumerate(source_sentence):

    probs = {}

    print(val)

    try:
      total_tran_freq = sum(source_to_target_frequencies[val].values())      
      for x in source_to_target_frequencies[val].keys():
        
        # print(val)
        # handle punctuation and stop words separately
        # they have highest frequencies hence risk of blowing up on prob scores

        if (x in stop_punct and val not in stop_punct):
          x_prob = 0.0
        else:
          try:
            x_prior = target_frequencies[x]/total_freqs
          except KeyError:
            x_prior = 0.0

          # s_t =  val + "-" + x

          try:
            x_post = source_to_target_frequencies[val][x] / total_tran_freq
          except KeyError:
            x_post = 0.0

          x_prob = x_prior * x_post
  
        probs[x] = x_prob

    except KeyError:
      x_prob = 0.0
      probs.append({x: x_prob})

    # print(probs)
    ind_new_word = probs.index(max(probs))
    new_word = target_word_index[ind_new_word]

    target.append(new_word)

  return target

# %%
_,_,_,_ = evaluate(target_words, target_word_index, target_frequencies, source_to_target_frequencies)
# Out:
# 0.6938620338480631

# %%
_, pred, ref, original = evaluate(target_words, target_word_index, target_frequencies, source_to_target_frequencies)
# Out:
# 0.6938620338480631

# %%
_, pred_, ref_, original_ = evaluate(target_words, target_word_index, target_frequencies, source_to_target_frequencies, total_st_frequencies)
# Out:
# scéal
# chathail
# freeman
# -
# téid
# mo
# dhearbhráthair
# 'un
# na
# dubh-charraice
# mí
# iúil
# a
# bhí
# ann
# i
# mbliadhain
# a
# 1854
# ,
# nuair
# a
# bhain
# an
# taisme
# seo
# dúinn
# .
# an
# dearbhráthair
# a
# ba
# sine
# agam
# ,
# seán
# freeman
# ,
# tugadh
# uainn
# go
# tobann
# é
# ,
# agus
# a
# thásc
# nó
# a
# thuairisc
# ní
# rabh
# againn
# le
# fagháil
# .
# tráthnóna
# breágh
# amháin
# ,
# chuaidh
# sé
# a
# dh'iascaireacht
# ;
# agus
# ,
# ach
# oiread
# agus
# dá
# slugadh
# an
# talamh
# é
# ,
# níor
# phill
# sé
# .
# bhí
# sé
# go
# maith
# i
# n-a
# shláinte
# agus
# nuair
# a
# bhí
# muid
# ag
# ár
# ndinneár
# bhí
# sé
# lán
# grinn
# agus
# cuideachta
# ;
# agus
# choinnigh
# sé
# an
# chuid
# a
# b'óige
# againn
# i
# dtrithibh
# gáiridhe
# go
# dtí
# go
# mb'éigean
# do
# m'athair
# bagar
# orainn
# agus
# cuireadh
# fear
# de
# mo
# chuid
# dearbhrátharach
# amach
# as
# an
# tseomra
# .
# iomlán
# na
# rudaí
# a
# thárla
# an
# lá
# sin
# ,
# tá
# siad
# comh
# soiléir
# in
# mo
# chuimhne
# is
# dá
# mbéinn
# ag
# amharc
# ortha
# le
# mo
# dhá
# shúil
# .
# 'tchím
# go
# fóill
# an
# caimbéal
# agus
# an
# an-chuma
# a
# chuireadh
# sé
# ar
# a
# aghaidh
# nuair
# nach
# mbíodh
# m'athair
# ag
# amharc
# agus
# d'fhágthaí
# muid-inne
# siocthaí
# leis
# na
# gáiridhe
# .
# bhí
# sé
# i
# ndiaidh
# a
# theacht
# 'un
# a'
# bhaile
# ar
# laethe
# saoire
# as
# coláisde
# na
# trionóide
# agus
# bhí
# faoi
# am
# maith
# a
# bheith
# aige
# fhad
# is
# bhéadh
# sé
# sa
# bhaile
# .
# mo
# dhuine
# bocht
# !
# is
# beag
# a
# bhí
# fhios
# aige
# caidé
# a
# bhí
# fá
# n-a
# choinne
# ag
# na
# laethe
# saoire
# céadna
# .
# amuigh
# sa
# tír
# a
# bhí
# muid
# 'n-ár
# gcomhnaidhe
# ,
# agus
# ag
# gasúr
# cosamhail
# le
# mo
# dhearbhráthair
# ba
# doiligh
# áit
# 'fhagháil
# a
# b'aoibhne
# ná
# an
# áit
# s'againne
# .
# bhí
# srutháin
# ag
# teacht
# ó'n
# tsliabh
# a
# bhí
# measach
# le
# bric
# agus
# nuair
# a
# thigeadh
# oidhche
# fhearthanna
# nó
# cioth
# maith
# trom
# bhíodh
# siad
# ar
# fheabhas
# fá
# choinne
# iascaireachta
# .
# nuair
# nach
# mbíodh
# tuile
# sna
# srutháin
# bhíodh
# seán
# ag
# iascaireacht
# ar
# phoill
# agus
# ar
# lochain
# le
# eangach
# carrán
# a
# rinne
# sé
# féin
# agus
# ba
# mhinic
# a
# thigeadh
# sé
# 'un
# a'
# bhaile
# agus
# basgaid
# bhreágh
# abhrais
# leis
# eadar
# bhric
# gheala
# is
# bhric
# dhubha
# .
# bhí
# lochanna
# maithe
# breac
# fá
# na
# sléibhte
# fosta
# .
# fear
# mór
# fairrge
# a
# bhí
# ann
# agus
# ba
# mhinic
# fá'n
# chladach
# é
# ,
# ag
# iascaireacht
# ó'n
# charraic
# agus
# amanna
# eile
# amuigh
# le
# bád
# .
# ag
# iascair
# -
# eacht
# ballán
# ó'n
# chladach
# a
# bhí
# sé
# an
# lá
# a
# d'imthigh
# sé
# agus
# nach
# rabhthar
# ábalta
# a
# thásg
# fhagháil
# ní
# ba
# mhó
# .
# bhí
# an
# fhairrge
# mhór
# ag
# briseadh
# ar
# chladach
# gharbh
# ghágach
# ,
# gann
# míle
# ó'n
# teach
# s'againne
# .
# eaglasach
# a
# bhí
# i
# m'athair
# agus
# ba
# do
# eaglais
# phrotastúnach
# na
# h-éireann
# a
# bhí
# sé
# ag
# déanamh
# seirbhíse
# .
# bhí
# paróiste
# mhór
# aige
# a
# rabh
# cladach
# fada
# faoithe
# agus
# í
# ag
# síneadh
# isteach
# i
# ndoimhneacht
# na
# tíre
# .
# ní
# rabh
# uaisle
# ar
# bith
# ag
# déanamh
# comhnaidhe
# fá'n
# áit
# agus
# ní
# rabh
# coimhéad
# ar
# bith
# dhá
# dhéanamh
# an
# fhiadhach
# .
# ní
# rabh
# aon
# fhear
# sa
# cheanntar
# a
# rabh
# gunna
# aige
# ach
# mo
# dhearbhráthair
# ,
# mar
# sin
# de
# bhí
# an
# tseilg
# uilig
# fúinn
# féin
# agus
# bhí
# sin
# againn
# samhradh
# is
# geimhreadh
# ,
# na
# sa
# tsamhradh
# ghnímís
# crotaigh
# ,
# colmáin
# ,
# coiníní
# ,
# agus
# girrfhiadhacha
# a
# lámhach
# .
# bhí
# an
# áit
# beó
# le
# girrfhiadhacha
# agus
# ar
# an
# adhbhar
# nach
# rabh
# conairt
# seilge
# ar
# bith
# ins
# an
# áit
# bhí
# seán
# 'na
# shealgaire
# mhór
# ,
# agus
# níorbh
# '
# é
# sin
# amháin
# ,
# ach
# ní
# rabh
# an
# dara
# sealgaire
# sa
# chonndae
# ach
# é
# féin
# .
# ní
# rabh
# sé
# 'na
# námhaid
# ag
# aon
# duine
# ,
# agus
# cé
# gur
# dhiamhaireach
# an
# dóigh
# ar
# imthigh
# sé
# ,
# ní
# thiocfadh
# linn
# a
# rádh
# gur
# fíomh
# a
# bhí
# dó
# le'r
# h-imreadh
# feall
# air
# .
# bhí
# muinntear
# na
# h-áite
# uilig
# go
# maith
# dó
# agus
# dá
# n-abrainn
# é
# ,
# rud
# saoilte
# aca
# dó
# .
# bhíodh
# siad
# ag
# cur
# scéaltach
# chuige
# i
# dtólamh
# ag
# innse
# dó
# áiteacha
# a
# rabh
# dobharchoin
# ,
# bruic
# agus
# cearca
# fraoich
# ,
# agus
# d'fhágadh
# siad
# a
# gcuid
# oibre
# ins
# na
# cuibhrinn
# agus
# thigeadh
# siad
# roimhe
# go
# bhfeiceadh
# siad
# caidé
# a
# bhíodh
# leis
# ina
# mhála
# ;
# nó
# nuair
# a
# tchíodh
# siad
# é
# ag
# pilleadh
# agus
# gunna
# nó
# slat
# iascaireachta
# ar
# a
# ghualainn
# ,
# scairtidís
# leis
# ,
# "
# a
# sheáin
# ,
# caidé
# mar
# d'éirigh
# leat
# indiu
# ?
# "
# níor
# shamhail
# muid
# ariamh
# ins
# an
# am
# sin
# ,
# nó
# go
# cionn
# fada
# 'na
# dhiaidh
# ,
# gur
# chuir
# námha
# deireadh
# leis
# nó
# gur
# h-imreadh
# feall
# air
# .
# agus
# 'na
# dhiaidh
# sin
# i
# lár
# an
# lae
# ghil
# ,
# gann
# míle
# ó'n
# bhaile
# ,
# cailleadh
# mo
# dhearbhráthair
# -
# tugadh
# ar
# shiubhal
# é
# mar
# shlugfadh
# an
# t-aer
# nó
# an
# talamh
# é
# .
# an
# deicheamhadh
# lá
# de
# mhí
# iúil
# a
# bhí
# ann
# ,
# lá
# comh
# breágh
# is
# d'iarrfadh
# do
# bhéal
# a
# bheith
# ann
# .
# indé
# roimhe
# sin
# a
# tháinig
# sé
# 'un
# a'
# bhaile
# as
# an
# choláisde
# agus
# bhí
# sé
# lán
# croidhe
# agus
# aignidh
# .
# an
# mhaidin
# sin
# ,
# nuair
# a
# mhuscail
# mé
# ,
# chualaidh
# mé
# é
# ag
# feadalaigh
# taoibh
# amuigh
# de'n
# fhuinneóig
# .
# ba
# é
# an
# fonn
# a
# bhí
# aige
# ,
# "
# vilikins
# and
# his
# dinah
# ,
# "
# abhrán
# a
# bhí
# go
# coitcheann
# ins
# an
# am
# .
# i
# dtólamh
# bhíodh
# fonn
# úr
# leis
# ag
# teacht
# 'un
# a'
# bhaile
# dó
# ,
# agus
# níorbh
# '
# fhéidir
# a
# thuirsiughadh
# de
# go
# bhfaghadh
# sé
# ceann
# úr
# eile
# .
# nuair
# a
# d'amharc
# mé
# amach
# bhí
# sé
# ag
# siubhal
# aníos
# is
# síos
# an
# léana
# ag
# baint
# an
# chasta
# as
# ruaim
# úir
# iascaireachta
# .
# bhí
# ceann
# de'n
# ruaim
# ceangailte
# ar
# chrann
# cuilinn
# aige
# agus
# é
# ag
# obair
# go
# deithneasach
# 'á
# réidhtiughadh
# -
# obair
# chéasta
# ,
# leóga
# .
# rith
# na
# maidne
# agus
# suas
# go
# h-am
# dinnéara
# ní
# rabh
# a
# dhath
# ar
# a
# umhail
# ach
# an
# obair
# a
# bhí
# eadar
# lámhaibh
# aige
# ,
# ag
# réidhtiughadh
# agus
# ag
# cur
# uirnéis
# na
# h-iascaireachta
# i
# ngléas
# .
# bhí
# an
# chuid
# a
# b'óige
# againn
# druidte
# taobh
# istigh
# de
# bhallaibh
# na
# scoile
# rith
# an
# ama
# ,
# ach
# chan
# ann
# a
# bhéamuis
# dá
# mba
# ar
# ár
# maith
# a
# bhéadh
# ,
# na
# dar
# linn
# gurbh
# '
# é
# ár
# gceart
# saoire
# a
# bheith
# againn
# an
# chéad
# lá
# a
# tháinig
# seán
# '
# un
# a
# '
# bhaile
# .
# ach
# mura
# rabh
# sé
# le
# feiceáil
# bhí
# sé
# le
# cluinstin
# againn
# ag
# obair
# go
# fuad
# ach
# agus
# de
# shíor
# ag
# feadalaigh
# "
# vilikins
# and
# his
# dinah
# .
# "
# am
# amháin
# chualaidh
# muid
# na
# géacha
# ag
# screadaigh
# go
# géibheannach
# thiar
# i
# gcúl
# an
# toighe
# .
# ba
# mhaith
# a
# bhí
# fhios
# againn
# caidé
# an
# tsiocair
# a
# fuair
# siad
# .
# bhí
# seán
# 'na
# ndiaidh
# agus
# é
# ag
# tarraingt
# cleiteach
# as
# a
# gcuid
# eiteóg
# gheall
# ar
# maghar
# mangach
# a
# cheangal
# .
# tamall
# i
# ndiaidh
# an
# mheadhoin
# lae
# tháinig
# sé
# isteach
# go
# teach
# na
# scoile
# agus
# d'iarr
# sé
# ar
# an
# mhaighistir
# cead
# a
# thabhairt
# damh-sa
# a
# ghabháil
# 'na
# bhaile
# mhóir
# go
# gceannuighinn
# cornán
# sreangán
# miotail
# dó
# .
# thug
# sé
# pighinn
# damh
# féin
# agus
# pighinn
# eile
# a
# bhéarfainn
# ar
# an
# tsreangán
# .
# san
# am
# sin
# dar
# liom
# gur
# mór
# an
# sínteanas
# pighinn
# .
# theastuigh
# an
# sreangán
# uaidh
# fá
# choinne
# a
# chur
# ar
# an
# tslait
# mhóir
# a
# bhíodh
# aige
# ag
# iascaireacht
# ar
# an
# fhairrge
# .
# d'iarr
# sé
# orm
# fosta
# a
# ghabháil
# isteach
# '
# toigh
# an
# ghréasaidhe
# agus
# giota
# céireach
# a
# fhagháil
# .
# ní
# thráchtfainn
# ar
# seo
# ar
# chor
# ar
# bith
# ,
# ach
# gurb
# '
# é
# go
# rabh
# daoine
# leamha
# ag
# rádh
# gurbh
# '
# eard
# a
# d'imthigh
# sé
# i
# ghainfhios
# .
# ach
# leig
# sinne
# na
# baramhlacha
# sin
# isteach
# ar
# chluais
# is
# amach
# ar
# chluais
# .
# leóga
# ní
# rabh
# faoi
# nó
# thairis
# ach
# tamall
# spóirt
# a
# bheith
# aige
# ar
# an
# iascaireacht
# .
# ar
# an
# trí
# a
# chlog
# a
# rinne
# muid
# ár
# ndinnéar
# ,
# an
# uair
# a
# choinnigh
# sé
# sinne
# ag
# gáiridhe
# faoi
# na
# h-an-chumaí
# a
# bhí
# sé
# a
# chur
# ar
# a
# aghaidh
# ,
# mar
# d'innis
# mé
# cheana
# féin
# .
# ag
# gabháil
# amach
# dúinn
# i
# ndiaidh
# ár
# ndinnéara
# bhí
# gasúr
# ag
# doras
# an
# halla
# agus
# bocsa
# baidhtí
# leis
# ina
# láimh
# .
# bhí
# dhá
# chineál
# baidhtí
# sa
# bhocsa
# ,
# ruacáin
# agus
# rudaí
# eile
# a
# dtugamuis
# slugaigh
# ortha
# .
# baintear
# na
# slugaigh
# sa
# tsláthach
# nuair
# a
# bíos
# tráigh
# ann
# .
# chaith
# an
# gasúr
# seo
# an
# mhaidín
# ag
# baint
# baidhtí
# do
# sheán
# .
# d'iarr
# sé
# cead
# air
# a
# bheith
# leis
# chuig
# an
# dubh-charraic
# ,
# ach
# ní
# leigfeadh
# seán
# leis
# é
# .
# "
# cá
# bhfuil
# tú
# ag
# gabháil
# ,
# a
# sheáin
# ?
# "
# arsa
# mo
# dhearbhráthair
# ,
# éamonn
# .
# b'eisean
# an
# dara
# duine
# de'n
# teaghlach
# .
# "
# tá
# mé
# ag
# gabháil
# chuig
# an
# dubh-charraic
# a
# dh'iascaireacht
# ballán
# ,
# "
# ar
# seisean
# ;
# "
# agus
# ar
# bhur
# mbás
# ná
# leanadh
# aon
# duine
# agaibh
# mé
# .
# "
# óg
# is
# mar
# bhí
# mé
# tháinig
# sé
# fríom
# sa
# bhomaite
# cad
# chuige
# nach
# leigfeadh
# sé
# aon
# duine
# leis
# .
# ba
# mhaith
# leis
# a
# bheith
# leis
# féin
# ar
# an
# uaigneas
# ,
# sa
# dóigh
# a
# dtiocfadh
# leis
# a
# rogha
# rud
# a
# dhéanamh
# ,
# aoibhneas
# agus
# pléisiúr
# a
# bheith
# aige
# cionn
# as
# a
# bheith
# sa
# bhaile
# arís
# agus
# racht
# a
# chuid
# smaointigheach
# a
# leigean
# amach
# gan
# aon
# duine
# a
# bheith
# ag
# amharc
# air
# .
# bhíodh
# baramhail
# agam
# i
# gcomhnaidhe
# ar
# na
# rudaí
# a
# mbíodh
# sé
# ag
# smaointiughadh
# ortha
# .
# leis
# an
# fhírinne
# a
# dhéanamh
# bhí
# mé
# iongantach
# dóirtthe
# dó
# cé
# go
# dtugadh
# sé
# a
# neamh-iongantas
# damh
# go
# minic
# .
# an
# lá
# seo
# bhí
# mé
# sásta
# i
# gceart
# cionnus
# gur
# orm
# a
# d'iarr
# sé
# a
# ghabháil
# fá
# choinne
# an
# tsreangáin
# agus
# na
# céireach
# .
# "
# a
# éamoinn
# ,
# "
# ar
# seisean
# ,
# "
# dhéanfaidh
# mé
# slad
# ar
# na
# balláin
# go
# dtí
# go
# mbidh
# an
# ghrian
# an
# aoirde
# sin
# '
# os
# cionn
# na
# mara
# thiar
# .
# annsin
# suas
# leis
# an
# chleite
# bhán
# agus
# isteach
# leis
# an
# trosc
# agus
# leis
# an
# cheann
# -
# crigirlín
# ,
# go
# mbí
# apollo
# leath
# bealaigh
# ó
# thuaidh
# ina
# bhád
# airgid
# agus
# go
# luighidh
# an
# fordorcha
# ar
# muir
# is
# ar
# tír
# .
# "
# d'imthigh
# sé
# síos
# an
# cabhsa
# agus
# cuaifín
# ceóil
# thuas
# aige
# ,
# a
# bhocsa
# baidhtí
# ina
# láimh
# leis
# agus
# a
# shlat
# iascaireachta
# ar
# a
# ghualainn
# .
# lean
# an
# dá
# mhadadh
# é
# agus
# a
# gcuid
# ruball
# síos
# leó
# ,
# na
# bhí
# eagla
# ortha
# go
# bpillfidhe
# iad
# .
# nuair
# a
# bhí
# sé
# ag
# an
# gheafta
# thug
# sé
# fá
# dear
# 'na
# dhiaidh
# iad
# agus
# bhagair
# sé
# 'un
# a'
# bhaile
# ortha
# ,
# agus
# nuair
# nach
# rabh
# siad
# sásta
# pilleadh
# dó
# chrom
# sé
# a
# chaitheamh
# cloch
# ortha
# .
# go
# gearr
# 'na
# dhiaidh
# sin
# chualaidh
# mé
# é
# ag
# scairtigh
# "
# ter
# .
# "
# "
# caidé
# ,
# a
# dhuine
# uasail
# ?
# "
# arsa
# glór
# i
# gceann
# de
# na
# cuibhrinn
# .
# "
# tar
# chuig
# an
# dubh-charraic
# uair
# i
# ndiaidh
# luighe
# gréine
# go
# dtugaidh
# tú
# an
# t-iasc
# 'un
# a'
# bhaile
# .
# "
# "
# maith
# go
# leór
# ,
# "
# ars
# an
# glór
# .
# annsin
# tháinig
# nótaí
# cumhaidheamhla
# "
# vilikins
# and
# his
# dinah
# "
# chugam
# go
# fann
# ar
# an
# ghaoith
# .
# mar
# sin
# a
# d'fhág
# seán
# an
# baile
# ar
# an
# 10
# adh
# lá
# de
# mhí
# iúil
# ,
# 1854
# ,
# agus
# ní
# fhacthas
# ní
# ba
# mhó
# é
# .
# tá
# sé
# follasach
# go
# leór
# nach
# rabh
# rún
# ar
# bith
# aige
# an
# baile
# fhágáil
# i
# ghainfhios
# agus
# 'na
# dhiaidh
# sin
# b'é
# an
# bharamhail
# a
# bhí
# ag
# saoithe
# na
# h-áite
# go
# rabh
# .
# níl
# fhios
# agam
# caidé
# a
# ba
# chiall
# damh
# ach
# bhí
# mé
# imnidheach
# fá
# sheán
# rith
# an
# lae
# sin
# agus
# mhéaduigh
# an
# imnidhe
# sin
# nuair
# a
# d'fhág
# sé
# an
# baile
# ar
# shéala
# a
# ghabháil
# chuig
# an
# dubh-charraic
# .
# i
# dtús
# ama
# bhí
# na
# smaointigheacha
# a
# bhí
# a
# '
# mo
# chiapadh
# gan
# chruth
# gan
# chuma
# ach
# de
# réir
# a
# chéile
# thoisigh
# siad
# a
# dh'éirghe
# ní
# ba
# ghlinne
# .
# bhí
# mé
# beó-intinneach
# ariamh
# ,
# agus
# ní
# luaithe
# a
# thigeadh
# smaointiughadh
# in
# mo
# cheann
# ná
# bhíodh
# sé
# '
# na
# phioctúir
# shoiléir
# ós
# comhair
# mo
# shúl
# .
# dar
# liom
# go
# bhféadfadh
# tonn
# a
# thabhairt
# amach
# ó'n
# charraic
# agus
# annsin
# chonnaic
# mé
# seán
# san
# uisce
# ag
# comhrac
# ar
# son
# a
# bheó
# .
# an
# samhradh
# roimhe
# sin
# cailleadh
# triúr
# dár
# gcuid
# tionóntaí
# i
# bpáirt
# eile
# de'n
# chonndae
# .
# aithreacha
# teaghlaigh
# a
# bhí
# ionnta
# agus
# báitheadh
# iad
# ag
# iascaireacht
# ballán
# ó'n
# chladach
# .
# tháinig
# tonn
# mhór
# ortha
# agus
# nigh
# sí
# ar
# shiubhal
# iad
# mar
# bhéadh
# sop
# leathaigh
# ann
# .
# aindeóin
# gur
# chuir
# mé
# i
# n-iúl
# damh
# féin
# go
# rabh
# seán
# '
# na
# shnámhaidhe
# bhreágh
# agus
# go
# dtiocfadh
# leis
# rud
# comhthrom
# a
# dhéanamh
# san
# uisce
# ,
# ní
# rabh
# mé
# ábalta
# buaidh
# '
# fhagháil
# ar
# an
# smaointiughadh
# a
# bhí
# a
# mo
# chriathrughadh
# rith
# an
# lae
# .
# bhítheas
# '
# á
# aidhbhsiughadh
# damh
# go
# rabh
# taisme
# le
# baint
# do
# sheán
# ,
# agus
# ní
# chuirfeadh
# a
# dhath
# sin
# as
# mo
# cheann
# nuair
# a
# luigh
# an
# ghrian
# agus
# chuaidh
# an
# dorchadas
# a
# thuitim
# .
# dar
# liom
# go
# bhféadfadh
# cramba
# a
# theacht
# ar
# sheán
# nuair
# a
# bhéadh
# sé
# san
# uisce
# .
# ní
# rabh
# cramba
# air
# ariamh
# agus
# níorbh
# '
# fheasach
# mé
# aon
# duine
# a
# rabh
# an
# t-éileamh
# sin
# air
# ,
# ach
# chualaidh
# mé
# mórán
# fá'n
# tolgan
# chéadna
# .
# cuireadh
# a
# luighe
# go
# luath
# mé
# ,
# na
# ní
# rabh
# mé
# ach
# ocht
# mbliadhna
# d'aois
# ,
# ach
# ní
# thiocfadh
# liom
# codladh
# .
# bhí
# mé
# ag
# éisteacht
# ,
# féacháil
# an
# gcluinfinn
# na
# madaidh
# ag
# tafann
# .
# an
# samhradh
# roimhe
# sin
# ,
# b'é
# sin
# an
# comhartha
# a
# gheibhinn
# i
# gcomhnaidhe
# go
# rabh
# seán
# slán
# sa
# bhaile
# ó'n
# iascaireacht
# .
# bhí
# sé
# i
# bhfad
# i
# ndiaidh
# na
# h-oidhche
# anois
# .
# an
# bheirt
# a
# ba
# sine
# ná
# mise
# ,
# éamonn
# agus
# somhairle
# ,
# tháinig
# siad
# isteach
# '
# un
# an
# tseomra
# agus
# lóchrann
# leó
# .
# bhí
# muid
# ár
# dtriúr
# ag
# codladh
# in
# aon
# seomra
# amháin
# ,
# éamonn
# agus
# somhairle
# ar
# leabaidh
# ,
# agus
# mise
# ar
# leabaidh
# bheag
# liom
# féin
# .
# bhí
# colbha
# na
# leaptha
# bige
# seo
# comh
# h-árd
# is
# nach
# rabh
# ann
# ach
# go
# mbínn
# ábalta
# a
# ghabháil
# isteach
# innte
# .
# d'fhág
# éamonn
# an
# lóchrann
# ar
# an
# tábla
# ós
# coinne
# an
# scátháin
# ,
# agus
# chrom
# sé
# anuas
# ós
# a
# chionn
# .
# tharraing
# sé
# biorán
# as
# a
# chóta
# agus
# chuaidh
# sé
# a
# chóiriughadh
# na
# buaice
# .
# lóchrann
# beag
# de'n
# tsean-déanamh
# a
# bhí
# ann
# :
# ní
# fhacaidh
# mé
# aon
# cheann
# de'n
# chineál
# ó
# bhí
# mé
# '
# mo
# ghasúr
# .
# "
# tá
# seán
# antráthach
# anocht
# ,
# "
# ar
# seisean
# ;
# "
# tá
# súil
# agam
# nach
# a
# dhath
# a
# tháinig
# air
# .
# "
# "
# caidé
# a
# thiocfadh
# air
# ?
# "
# arsa
# somhairle
# .
# duine
# dúr
# dall-inntleachtach
# a
# bhí
# ann-san
# .
# scaoil
# sé
# an
# crios
# a
# bhí
# fá
# n-a
# chum
# ,
# agus
# chaith
# sé
# uaidh
# í
# .
# 0

# %%
len(target_word_index)
# Out:
# 25737

# %% [markdown]
# ## New Section

# %%
ref_ = [x[0] for x in ref]
joined = list(zip(pred_, ref_, original_))
for i in range(len(joined)):
  if i == 1:
    print("Pred","\t", joined[i][0], "\nRef\t", joined[i][1], "\nOr\t", joined[i][2])
    break
# Out:
# Pred 	 ['gearrsmaointiú', 'gearrsmaointiú', 'gearrsmaointiú', 'gearrsmaointiú', 'gearrsmaointiú', 'gearrsmaointiú', 'gearrsmaointiú', 'gearrsmaointiú', 'gearrsmaointiú', 'gearrsmaointiú', 'gearrsmaointiú', 'gearrsmaointiú', 'gearrsmaointiú', 'gearrsmaointiú', 'gearrsmaointiú', 'gearrsmaointiú', 'gearrsmaointiú', 'gearrsmaointiú']
# Ref	 ['mí', 'iúil', 'a', 'bhí', 'ann', 'i', 'mbliain', 'a', '1854', ',', 'nuair', 'a', 'bhain', 'an', 'taisme', 'seo', 'dúinn', '.']
# Or	 ['mí', 'iúil', 'a', 'bhí', 'ann', 'i', 'mbliadhain', 'a', '1854', ',', 'nuair', 'a', 'bhain', 'an', 'taisme', 'seo', 'dúinn', '.']

# %%
source_to_target_frequencies["se"]
# Out:
# {'<PAD>': 7, 'seo': 1}

# %%
for key in source_to_target_frequencies.keys():
  if key[:4] == "n-a-":
    print(key, ": ",source_to_target_frequencies[key])
# Out:
# n-a-lena :  65
# n-a-n-ál :  1
# n-a-fána :  19
# n-a-ina :  166
# n-a-arna :  5
# n-a-dona :  3
# n-a-agna :  2
# n-a-dena :  2
# n-a-óna :  8
# n-a-anam :  3
# n-a-na :  4
# n-a-nach :  1

# %%
target_frequencies[""]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-65e89c5adf1f> in <module>
# ----> 1 target_frequencies[""]
#
# KeyError: ''

# %%
print((target_frequencies["móire"] / sum(target_frequencies.values())) * (source_to_target_frequencies["mbliadhain-móire"]))
print(((target_frequencies["mbliain"] / sum(target_frequencies.values())) * (source_to_target_frequencies["mbliadhain-mbliain"])))
# Out:
# 7.883851162744861e-05
# 1.4782220930146615e-05

# %%
print(target_frequencies["móire"], target_frequencies["mbliain"])
# Out:
# 64 6

# %%
"'un" in list(adv.stopwords["irish"])
# Out:
# False

# %%
target_frequencies['bhaile']
# Out:
# 1241

# %%
val_indices = {}
for ind,val in enumerate(x):
  if val != 0:
    val_indices[ind] = val

# %%
print(sum(val_indices.values()), len(val_indices), max(val_indices.values()), max(val_indices, key=val_indices.get))
# Out:
# 3.695876933785215e-06 69 1.242070311196917e-06 21712

# %%
target_word_index[21712]
# Out:
# 'a'

# %%
target_word_index

# %%
len(input_word_index)
# Out:
# 31039

# %%
corpus_bleu(ref,pred)
# Out:
# 0.13979355309562722

# %%
print(input_text[0].split(" "))
target = predict(input_text[0].split(" "),target_words, target_word_index, target_frequencies, source_to_target_frequencies)
# Out:
# ['cinnte', 'go', 'leór', ',', 'thiocfadh', 'dóbhtha', 'bás', 'a', 'fhagháil', 'ar', 'imeall', 'an', 'phuill', 'udaí', '.']

# %%
source_to_target_frequencies["scéal-scéal"]
# Out:
# 244

# %%
pred[0]
# Out:
# ['a', ',', 'a', ',', 'an', 'mo', 'a', 'an', 'na', ',']

# %%
source_to_target_frequencies["scéal-is"]
# Out:
# 3

# %%
target_frequencies["an"]
# Out:
# 35500

# %%
t_f = {k: v for k, v in sorted(target_frequencies.items(), key=lambda item: item[1], reverse=True)}

# %%
print((t_f["a"] / sum(t_f.values())) * (source_to_target_frequencies["scéal-a"]))
print(((t_f["scéal"] / sum(t_f.values())) * (source_to_target_frequencies["scéal-scéal"])))
# Out:
# 1.0082952896453006
# 0.223625438231258

# %%
from difflib import SequenceMatcher

x = "d'fhágamar"
y = "d'fhág"

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio(), len(min(x,y))/len(max(x,y))

similar(x,y)
# Out:
# (0.75, 0.6)
